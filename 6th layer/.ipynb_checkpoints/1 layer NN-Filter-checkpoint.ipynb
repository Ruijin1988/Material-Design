# %%
import scipy.io
import numpy as np
import theano
import theano.tensor as T
from theano.tensor.signal import pool
import random

#import input data
force = scipy.io.loadmat('true.mat')
neurons = scipy.io.loadmat('hidstates5th_WB_recon_30neuron')
neuron5=neurons['xtr'].T

neuron_train = neuron5[0:80]
neuron_test = neuron5[80:100]

force = scipy.io.loadmat('true.mat')
data_label=np.asarray(force['skt']).reshape(-1)
label_y=(data_label-np.mean(data_label))/np.std(data_label)
label_train=label_y[0:80]
label_test=label_y[80:100]

# %%
neuron_train.shape
# Out:
# (80L, 30L)

# %%
#######################
# 5to6 layer training #
#######################
class RBM_NN(object):
    def __init__(self, input, n_in, n_out):
        self.W = theano.shared(value=np.zeros((n_in, n_out),dtype=theano.config.floatX),name='W',borrow=True)
        self.b = theano.shared(value=np.zeros((n_out,),dtype=theano.config.floatX),name='b',borrow=True)               
        self.y_pred = T.dot(input, self.W)+self.b      
        self.params = [self.W, self.b]
        
    def difference(self,y):
        return T.mean(abs(self.y_pred-T.reshape(y,[10,1])))
        
    
def load_data(data1, data2):
    #data1=neurons['xtr']
    #data2=force['skt']
    def shared_dataset(data1,data2,borrow=True):
        shared_x = theano.shared(np.asarray(data1, dtype=theano.config.floatX),borrow=True)
        shared_y = theano.shared(np.asarray(data2, dtype=theano.config.floatX),borrow=True)
        return shared_x, T.cast(shared_y,'float64')
    
    train_set_x, train_set_y = shared_dataset(data1,data2)
    rval = [(train_set_x, train_set_y)]
    return rval

def sgd_optimization(learning_rate=0.01, n_epochs=2000, data1=neuron_train, data2=label_train,
                     data3=neuron_test, data4=label_test, batch_size=10):
    
    datasets_train = load_data(data1, data2)
    datasets_test = load_data(data3,data4)
    
    train_set_x, train_set_y = datasets_train[0]
    test_set_x, test_set_y = datasets_test[0]
    
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] // batch_size
    n_test_batches = test_set_x.get_value(borrow=True).shape[0] // batch_size
    
    
    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')
    index = T.lscalar()
    x = T.matrix('x')
    y = T.vector('y')
    
    classifier = RBM_NN(input=x, n_in=30 * 1, n_out=1)
    cost = classifier.difference(y)
    
    test_model = theano.function(inputs=[index],
                                outputs=classifier.difference(y),
                                givens={
            x:test_set_x[index*batch_size:(index+1)*batch_size],
            y:test_set_y[index*batch_size:(index+1)*batch_size]
        })
    
    #test_model = theano.function(inputs=[index], outputs=cost,
    #                            givens={x:test_set_x[index*batch_size:(index+1)*batch_size],
    #                                   y:test_set_y[index*batch_size:(index+1)*batch_size]}
    #                            )
    
    g_W = T.grad(cost=cost, wrt=classifier.W)
    g_b = T.grad(cost=cost, wrt=classifier.b)
    
    updates = [(classifier.W, classifier.W-learning_rate*g_W),
               (classifier.b, classifier.b-learning_rate*g_b)]
    
    #print cost
    train_model = theano.function(inputs=[index],
                                  outputs=cost,
                                  updates=updates,
                                 givens={x:train_set_x[index*batch_size:(index+1)*batch_size],
                                         y:train_set_y[index*batch_size:(index+1)*batch_size]}
                                 ) 
    
    
    ###############
    # TRAIN MODEL #
    ###############
    print('... training the model')
    
    epoch=0
    while (epoch<n_epochs):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            minibatch_avg_cost=train_model(minibatch_index)
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index
            #print iter
            if (iter + 1) % 4 == 0:
                # compute zero-one loss on validation set
                losses = [train_model(i) for i in range(n_train_batches)]
                this_loss = np.mean(losses)
                
                print "Epoch {0}, Minibatch {1}/{2}, Training Error= {3}".format(epoch,minibatch_index+1,n_train_batches,
                                                                       this_loss)
                
                
        if epoch%2==0:
            test_losses = [test_model(i) for i in range(n_test_batches)]
            #print classifier.W.get_value()
            test_score = np.mean(test_losses)            
            print "Testing Score= {0}".format(test_score)

    return [classifier.W, classifier.b]
# run
W,b=sgd_optimization()
# Out:
# ... building the model
# ... training the model
# Epoch 1, Minibatch 4/8, Test Error= 0.735858013286
# Epoch 1, Minibatch 8/8, Test Error= 0.734997247735
# Epoch 2, Minibatch 4/8, Test Error= 0.720364911349
# Epoch 2, Minibatch 8/8, Test Error= 0.720515052134
# Testing Score= 0.924631765166
# Epoch 3, Minibatch 4/8, Test Error= 0.715010747773
# Epoch 3, Minibatch 8/8, Test Error= 0.714021059036
# Epoch 4, Minibatch 4/8, Test Error= 0.708110747773
# Epoch 4, Minibatch 8/8, Test Error= 0.707422706916
# Testing Score= 0.926331765166
# Epoch 5, Minibatch 4/8, Test Error= 0.699135747773
# Epoch 5, Minibatch 8/8, Test Error= 0.701296059036
# Epoch 6, Minibatch 4/8, Test Error= 0.695634153231
# Epoch 6, Minibatch 8/8, Test Error= 0.697881112172
# Testing Score= 0.925831765166
# Epoch 7, Minibatch 4/8, Test Error= 0.68704529454
# Epoch 7, Minibatch 8/8, Test Error= 0.692831112172
# Epoch 8, Minibatch 4/8, Test Error= 0.683837782197
# Epoch 8, Minibatch 8/8, Test Error= 0.68514809346
# Testing Score= 0.923231765166
# Epoch 9, Minibatch 4/8, Test Error= 0.67942080091
# Epoch 9, Minibatch 8/8, Test Error= 0.680880516434
# Epoch 10, Minibatch 4/8, Test Error= 0.67493453103
# Epoch 10, Minibatch 8/8, Test Error= 0.677044294821
# Testing Score= 0.915831765166
# Epoch 11, Minibatch 4/8, Test Error= 0.673516885553
# Epoch 11, Minibatch 8/8, Test Error= 0.674480290139
# Epoch 12, Minibatch 4/8, Test Error= 0.666824343141
# Epoch 12, Minibatch 8/8, Test Error= 0.673953923683
# Testing Score= 0.912731765166
# Epoch 13, Minibatch 4/8, Test Error= 0.665783732371
# Epoch 13, Minibatch 8/8, Test Error= 0.668553245493
# Epoch 14, Minibatch 4/8, Test Error= 0.662633732371
# Epoch 14, Minibatch 8/8, Test Error= 0.668864111572
# Testing Score= 0.905231765166
# Epoch 15, Minibatch 4/8, Test Error= 0.661918437242
# Epoch 15, Minibatch 8/8, Test Error= 0.667475585826
# Epoch 16, Minibatch 4/8, Test Error= 0.656658732371
# Epoch 16, Minibatch 8/8, Test Error= 0.663703923683
# Testing Score= 0.900031765166
# Epoch 17, Minibatch 4/8, Test Error= 0.655843437242
# Epoch 17, Minibatch 8/8, Test Error= 0.658756130509
# Epoch 18, Minibatch 4/8, Test Error= 0.653033732371
# Epoch 18, Minibatch 8/8, Test Error= 0.658878816453
# Testing Score= 0.890231765166
# Epoch 19, Minibatch 4/8, Test Error= 0.652036061762
# Epoch 19, Minibatch 8/8, Test Error= 0.652602095237
# Epoch 20, Minibatch 4/8, Test Error= 0.647849685968
# Epoch 20, Minibatch 8/8, Test Error= 0.654543628565
# Testing Score= 0.883130074273
# Epoch 21, Minibatch 4/8, Test Error= 0.646860981026
# Epoch 21, Minibatch 8/8, Test Error= 0.652778923683
# Epoch 22, Minibatch 4/8, Test Error= 0.644735981026
# Epoch 22, Minibatch 8/8, Test Error= 0.656844376092
# Testing Score= 0.879130074273
# Epoch 23, Minibatch 4/8, Test Error= 0.639857184503
# Epoch 23, Minibatch 8/8, Test Error= 0.651615932455
# Epoch 24, Minibatch 4/8, Test Error= 0.641420685897
# Epoch 24, Minibatch 8/8, Test Error= 0.650376647277
# Testing Score= 0.874530074273
# Epoch 25, Minibatch 4/8, Test Error= 0.637148636608
# Epoch 25, Minibatch 8/8, Test Error= 0.648715932455
# Epoch 26, Minibatch 4/8, Test Error= 0.637420685897
# Epoch 26, Minibatch 8/8, Test Error= 0.646039782198
# Testing Score= 0.876630074273
# Epoch 27, Minibatch 4/8, Test Error= 0.636276127425
# Epoch 27, Minibatch 8/8, Test Error= 0.644068628565
# Epoch 28, Minibatch 4/8, Test Error= 0.63465502245
# Epoch 28, Minibatch 8/8, Test Error= 0.643235263489
# Testing Score= 0.876130074273
# Epoch 29, Minibatch 4/8, Test Error= 0.632483959765
# Epoch 29, Minibatch 8/8, Test Error= 0.642585263489
# Epoch 30, Minibatch 4/8, Test Error= 0.631619773507
# Epoch 30, Minibatch 8/8, Test Error= 0.643060828149
# Testing Score= 0.871730074273
# Epoch 31, Minibatch 4/8, Test Error= 0.633381574557
# Epoch 31, Minibatch 8/8, Test Error= 0.638361758253
# Epoch 32, Minibatch 4/8, Test Error= 0.63054360722
# Epoch 32, Minibatch 8/8, Test Error= 0.637273330094
# Testing Score= 0.872430074273
# Epoch 33, Minibatch 4/8, Test Error= 0.629389435913
# Epoch 33, Minibatch 8/8, Test Error= 0.636706420659
# Epoch 34, Minibatch 4/8, Test Error= 0.63004467734
# Epoch 34, Minibatch 8/8, Test Error= 0.638185263489
# Testing Score= 0.871130074273
# Epoch 35, Minibatch 4/8, Test Error= 0.629360595387
# Epoch 35, Minibatch 8/8, Test Error= 0.638415589628
# Epoch 36, Minibatch 4/8, Test Error= 0.626708125686
# Epoch 36, Minibatch 8/8, Test Error= 0.635760263489
# Testing Score= 0.871030074273
# Epoch 37, Minibatch 4/8, Test Error= 0.626819979478
# Epoch 37, Minibatch 8/8, Test Error= 0.634585606316
# Epoch 38, Minibatch 4/8, Test Error= 0.625513553517
# Epoch 38, Minibatch 8/8, Test Error= 0.631711758253
# Testing Score= 0.871730074273
# Epoch 39, Minibatch 4/8, Test Error= 0.6234217577
# Epoch 39, Minibatch 8/8, Test Error= 0.631532255617
# Epoch 40, Minibatch 4/8, Test Error= 0.623308125686
# Epoch 40, Minibatch 8/8, Test Error= 0.631785606316
# Testing Score= 0.875330074273
# Epoch 41, Minibatch 4/8, Test Error= 0.620961754795
# Epoch 41, Minibatch 8/8, Test Error= 0.632315932455
# Epoch 42, Minibatch 4/8, Test Error= 0.622808125686
# Epoch 42, Minibatch 8/8, Test Error= 0.627561758253
# Testing Score= 0.874330074273
# Epoch 43, Minibatch 4/8, Test Error= 0.6213717577
# Epoch 43, Minibatch 8/8, Test Error= 0.629060263489
# Epoch 44, Minibatch 4/8, Test Error= 0.620907571442
# Epoch 44, Minibatch 8/8, Test Error= 0.628355502011
# Testing Score= 0.871830074273
# Epoch 45, Minibatch 4/8, Test Error= 0.619183125686
# Epoch 45, Minibatch 8/8, Test Error= 0.621928254983
# Epoch 46, Minibatch 4/8, Test Error= 0.620701949562
# Epoch 46, Minibatch 8/8, Test Error= 0.625509498686
# Testing Score= 0.872330074273
# Epoch 47, Minibatch 4/8, Test Error= 0.616541653395
# Epoch 47, Minibatch 8/8, Test Error= 0.625785606316
# Epoch 48, Minibatch 4/8, Test Error= 0.617508125686
# Epoch 48, Minibatch 8/8, Test Error= 0.624460263489
# Testing Score= 0.872230074273
# Epoch 49, Minibatch 4/8, Test Error= 0.617316074713
# Epoch 49, Minibatch 8/8, Test Error= 0.618760526377
# Epoch 50, Minibatch 4/8, Test Error= 0.618661822165
# Epoch 50, Minibatch 8/8, Test Error= 0.620142702869
# Testing Score= 0.873530074273
# Epoch 51, Minibatch 4/8, Test Error= 0.617186822165
# Epoch 51, Minibatch 8/8, Test Error= 0.621469548483
# Epoch 52, Minibatch 4/8, Test Error= 0.615011143975
# Epoch 52, Minibatch 8/8, Test Error= 0.621103727637
# Testing Score= 0.871230074273
# Epoch 53, Minibatch 4/8, Test Error= 0.6131717577
# Epoch 53, Minibatch 8/8, Test Error= 0.617095454567
# Epoch 54, Minibatch 4/8, Test Error= 0.612933249632
# Epoch 54, Minibatch 8/8, Test Error= 0.619055641655
# Testing Score= 0.874130074273
# Epoch 55, Minibatch 4/8, Test Error= 0.614772161399
# Epoch 55, Minibatch 8/8, Test Error= 0.616939519095
# Epoch 56, Minibatch 4/8, Test Error= 0.615267283334
# Epoch 56, Minibatch 8/8, Test Error= 0.613090369592
# Testing Score= 0.873930074273
# Epoch 57, Minibatch 4/8, Test Error= 0.612032571442
# Epoch 57, Minibatch 8/8, Test Error= 0.618244548483
# Epoch 58, Minibatch 4/8, Test Error= 0.614467283334
# Epoch 58, Minibatch 8/8, Test Error= 0.615956827515
# Testing Score= 0.872930074273
# Epoch 59, Minibatch 4/8, Test Error= 0.608608663839
# Epoch 59, Minibatch 8/8, Test Error= 0.614614519095
# Epoch 60, Minibatch 4/8, Test Error= 0.610461143975
# Epoch 60, Minibatch 8/8, Test Error= 0.616625650881
# Testing Score= 0.873330074273
# Epoch 61, Minibatch 4/8, Test Error= 0.607654063273
# Epoch 61, Minibatch 8/8, Test Error= 0.61869792543
# Epoch 62, Minibatch 4/8, Test Error= 0.610792324117
# Epoch 62, Minibatch 8/8, Test Error= 0.61384754874
# Testing Score= 0.873930074273
# Epoch 63, Minibatch 4/8, Test Error= 0.607393174613
# Epoch 63, Minibatch 8/8, Test Error= 0.610681902433
# Epoch 64, Minibatch 4/8, Test Error= 0.607833249632
# Epoch 64, Minibatch 8/8, Test Error= 0.615016834489
# Testing Score= 0.875930074273
# Epoch 65, Minibatch 4/8, Test Error= 0.605410104186
# Epoch 65, Minibatch 8/8, Test Error= 0.607916607304
# Epoch 66, Minibatch 4/8, Test Error= 0.610202190786
# Epoch 66, Minibatch 8/8, Test Error= 0.610639519095
# Testing Score= 0.875530074273
# Epoch 67, Minibatch 4/8, Test Error= 0.606328988355
# Epoch 67, Minibatch 8/8, Test Error= 0.609567702869
# Epoch 68, Minibatch 4/8, Test Error= 0.605422167332
# Epoch 68, Minibatch 8/8, Test Error= 0.616602611991
# Testing Score= 0.872930074273
# Epoch 69, Minibatch 4/8, Test Error= 0.60484222184
# Epoch 69, Minibatch 8/8, Test Error= 0.606166607304
# Epoch 70, Minibatch 4/8, Test Error= 0.610637266045
# Epoch 70, Minibatch 8/8, Test Error= 0.613021863876
# Testing Score= 0.876430074273
# Epoch 71, Minibatch 4/8, Test Error= 0.602710104186
# Epoch 71, Minibatch 8/8, Test Error= 0.614157949585
# Epoch 72, Minibatch 4/8, Test Error= 0.603407323208
# Epoch 72, Minibatch 8/8, Test Error= 0.607869446207
# Testing Score= 0.874230074273
# Epoch 73, Minibatch 4/8, Test Error= 0.605515037072
# Epoch 73, Minibatch 8/8, Test Error= 0.607544526943
# Epoch 74, Minibatch 4/8, Test Error= 0.605647161399
# Epoch 74, Minibatch 8/8, Test Error= 0.607019526943
# Testing Score= 0.876230074273
# Epoch 75, Minibatch 4/8, Test Error= 0.600177467137
# Epoch 75, Minibatch 8/8, Test Error= 0.610947582603
# Epoch 76, Minibatch 4/8, Test Error= 0.601312117535
# Epoch 76, Minibatch 8/8, Test Error= 0.61034792543
# Testing Score= 0.877030074273
# Epoch 77, Minibatch 4/8, Test Error= 0.605769296683
# Epoch 77, Minibatch 8/8, Test Error= 0.605619446207
# Epoch 78, Minibatch 4/8, Test Error= 0.605002409253
# Epoch 78, Minibatch 8/8, Test Error= 0.604217702869
# Testing Score= 0.878030074273
# Epoch 79, Minibatch 4/8, Test Error= 0.599286583478
# Epoch 79, Minibatch 8/8, Test Error= 0.603669446207
# Epoch 80, Minibatch 4/8, Test Error= 0.60355845075
# Epoch 80, Minibatch 8/8, Test Error= 0.604884498686
# Testing Score= 0.877930074273
# Epoch 81, Minibatch 4/8, Test Error= 0.601505105363
# Epoch 81, Minibatch 8/8, Test Error= 0.603669526943
# Epoch 82, Minibatch 4/8, Test Error= 0.601475081038
# Epoch 82, Minibatch 8/8, Test Error= 0.600431902433
# Testing Score= 0.878430074273
# Epoch 83, Minibatch 4/8, Test Error= 0.600587910841
# Epoch 83, Minibatch 8/8, Test Error= 0.600852994102
# Epoch 84, Minibatch 4/8, Test Error= 0.600259785909
# Epoch 84, Minibatch 8/8, Test Error= 0.599406902433
# Testing Score= 0.880430074273
# Epoch 85, Minibatch 4/8, Test Error= 0.600275081038
# Epoch 85, Minibatch 8/8, Test Error= 0.601069446207
# Epoch 86, Minibatch 4/8, Test Error= 0.600006331285
# Epoch 86, Minibatch 8/8, Test Error= 0.602891491662
# Testing Score= 0.880030074273
# Epoch 87, Minibatch 4/8, Test Error= 0.596585217729
# Epoch 87, Minibatch 8/8, Test Error= 0.602636154067
# Epoch 88, Minibatch 4/8, Test Error= 0.594006114587
# Epoch 88, Minibatch 8/8, Test Error= 0.603565750001
# Testing Score= 0.879530074273
# Epoch 89, Minibatch 4/8, Test Error= 0.594312100925
# Epoch 89, Minibatch 8/8, Test Error= 0.601639518293
# Epoch 90, Minibatch 4/8, Test Error= 0.591914896267
# Epoch 90, Minibatch 8/8, Test Error= 0.599948118506
# Testing Score= 0.882230074273
# Epoch 91, Minibatch 4/8, Test Error= 0.594972005032
# Epoch 91, Minibatch 8/8, Test Error= 0.602297582603
# Epoch 92, Minibatch 4/8, Test Error= 0.594238875852
# Epoch 92, Minibatch 8/8, Test Error= 0.597519526943
# Testing Score= 0.879730074273
# Epoch 93, Minibatch 4/8, Test Error= 0.594637298992
# Epoch 93, Minibatch 8/8, Test Error= 0.601507287474
# Epoch 94, Minibatch 4/8, Test Error= 0.593121031472
# Epoch 94, Minibatch 8/8, Test Error= 0.599399223165
# Testing Score= 0.881330074273
# Epoch 95, Minibatch 4/8, Test Error= 0.593918492614
# Epoch 95, Minibatch 8/8, Test Error= 0.598616491662
# Epoch 96, Minibatch 4/8, Test Error= 0.592971031472
# Epoch 96, Minibatch 8/8, Test Error= 0.592916607304
# Testing Score= 0.882430074273
# Epoch 97, Minibatch 4/8, Test Error= 0.593640037072
# Epoch 97, Minibatch 8/8, Test Error= 0.597466491662
# Epoch 98, Minibatch 4/8, Test Error= 0.594037923079
# Epoch 98, Minibatch 8/8, Test Error= 0.593363340711
# Testing Score= 0.883530074273
# Epoch 99, Minibatch 4/8, Test Error= 0.593455128495
# Epoch 99, Minibatch 8/8, Test Error= 0.597061154067
# Epoch 100, Minibatch 4/8, Test Error= 0.592885949711
# Epoch 100, Minibatch 8/8, Test Error= 0.596070858939
# Testing Score= 0.882930074273
# Epoch 101, Minibatch 4/8, Test Error= 0.588674637158
# Epoch 101, Minibatch 8/8, Test Error= 0.595385720613
# Epoch 102, Minibatch 4/8, Test Error= 0.59126529576
# Epoch 102, Minibatch 8/8, Test Error= 0.595486154067
# Testing Score= 0.885230074273
# Epoch 103, Minibatch 4/8, Test Error= 0.591912923079
# Epoch 103, Minibatch 8/8, Test Error= 0.594211124381
# Epoch 104, Minibatch 4/8, Test Error= 0.589922005032
# Epoch 104, Minibatch 8/8, Test Error= 0.592124695845
# Testing Score= 0.884830074273
# Epoch 105, Minibatch 4/8, Test Error= 0.588655193212
# Epoch 105, Minibatch 8/8, Test Error= 0.591433874999
# Epoch 106, Minibatch 4/8, Test Error= 0.589296031472
# Epoch 106, Minibatch 8/8, Test Error= 0.592132960858
# Testing Score= 0.885130074273
# Epoch 107, Minibatch 4/8, Test Error= 0.590153108343
# Epoch 107, Minibatch 8/8, Test Error= 0.590433874999
# Epoch 108, Minibatch 4/8, Test Error= 0.586134342029
# Epoch 108, Minibatch 8/8, Test Error= 0.592060720613
# Testing Score= 0.885430074273
# Epoch 109, Minibatch 4/8, Test Error= 0.588597005032
# Epoch 109, Minibatch 8/8, Test Error= 0.589659400716
# Epoch 110, Minibatch 4/8, Test Error= 0.5876393222
# Epoch 110, Minibatch 8/8, Test Error= 0.58848456042
# Testing Score= 0.887430074273
# Epoch 111, Minibatch 4/8, Test Error= 0.592487388363
# Epoch 111, Minibatch 8/8, Test Error= 0.58959512077
# Epoch 112, Minibatch 4/8, Test Error= 0.589380357725
# Epoch 112, Minibatch 8/8, Test Error= 0.58749628483
# Testing Score= 0.885463167166
# Epoch 113, Minibatch 4/8, Test Error= 0.586316389283
# Epoch 113, Minibatch 8/8, Test Error= 0.59100729893
# Epoch 114, Minibatch 4/8, Test Error= 0.586739974394
# Epoch 114, Minibatch 8/8, Test Error= 0.587553629667
# Testing Score= 0.889330074273
# Epoch 115, Minibatch 4/8, Test Error= 0.585845078699
# Epoch 115, Minibatch 8/8, Test Error= 0.589770858939
# Epoch 116, Minibatch 4/8, Test Error= 0.586028108343
# Epoch 116, Minibatch 8/8, Test Error= 0.584604976352
# Testing Score= 0.891563167166
# Epoch 117, Minibatch 4/8, Test Error= 0.585942868571
# Epoch 117, Minibatch 8/8, Test Error= 0.587859934226
# Epoch 118, Minibatch 4/8, Test Error= 0.584037348831
# Epoch 118, Minibatch 8/8, Test Error= 0.58564357987
# Testing Score= 0.890263167166
# Epoch 119, Minibatch 4/8, Test Error= 0.583582818774
# Epoch 119, Minibatch 8/8, Test Error= 0.587019639097
# Epoch 120, Minibatch 4/8, Test Error= 0.583202745827
# Epoch 120, Minibatch 8/8, Test Error= 0.583922446463
# Testing Score= 0.893963167166
# Epoch 121, Minibatch 4/8, Test Error= 0.583922005032
# Epoch 121, Minibatch 8/8, Test Error= 0.583518138409
# Epoch 122, Minibatch 4/8, Test Error= 0.584178108343
# Epoch 122, Minibatch 8/8, Test Error= 0.58390637701
# Testing Score= 0.894963167166
# Epoch 123, Minibatch 4/8, Test Error= 0.583310949711
# Epoch 123, Minibatch 8/8, Test Error= 0.584813572023
# Epoch 124, Minibatch 4/8, Test Error= 0.581005193212
# Epoch 124, Minibatch 8/8, Test Error= 0.585820979508
# Testing Score= 0.894863167166
# Epoch 125, Minibatch 4/8, Test Error= 0.583120078699
# Epoch 125, Minibatch 8/8, Test Error= 0.581822446463
# Epoch 126, Minibatch 4/8, Test Error= 0.581246031472
# Epoch 126, Minibatch 8/8, Test Error= 0.582378629667
# Testing Score= 0.891263167166
# Epoch 127, Minibatch 4/8, Test Error= 0.581843979355
# Epoch 127, Minibatch 8/8, Test Error= 0.584407057159
# Epoch 128, Minibatch 4/8, Test Error= 0.583527980588
# Epoch 128, Minibatch 8/8, Test Error= 0.580697446463
# Testing Score= 0.897563167166
# Epoch 129, Minibatch 4/8, Test Error= 0.580290923336
# Epoch 129, Minibatch 8/8, Test Error= 0.581044691969
# Epoch 130, Minibatch 4/8, Test Error= 0.580139974394
# Epoch 130, Minibatch 8/8, Test Error= 0.582535230882
# Testing Score= 0.896563167166
# Epoch 131, Minibatch 4/8, Test Error= 0.576991641612
# Epoch 131, Minibatch 8/8, Test Error= 0.58048349523
# Epoch 132, Minibatch 4/8, Test Error= 0.580170078699
# Epoch 132, Minibatch 8/8, Test Error= 0.580243762496
# Testing Score= 0.903463167166
# Epoch 133, Minibatch 4/8, Test Error= 0.578707160908
# Epoch 133, Minibatch 8/8, Test Error= 0.578582151335
# Epoch 134, Minibatch 4/8, Test Error= 0.57789857452
# Epoch 134, Minibatch 8/8, Test Error= 0.579784569256
# Testing Score= 0.906463167166
# Epoch 135, Minibatch 4/8, Test Error= 0.578414974394
# Epoch 135, Minibatch 8/8, Test Error= 0.577538253732
# Epoch 136, Minibatch 4/8, Test Error= 0.577583265122
# Epoch 136, Minibatch 8/8, Test Error= 0.581237472331
# Testing Score= 0.900963167166
# Epoch 137, Minibatch 4/8, Test Error= 0.578720078699
# Epoch 137, Minibatch 8/8, Test Error= 0.580831568999
# Epoch 138, Minibatch 4/8, Test Error= 0.577178024447
# Epoch 138, Minibatch 8/8, Test Error= 0.579535712555
# Testing Score= 0.899763167166
# Epoch 139, Minibatch 4/8, Test Error= 0.580160311361
# Epoch 139, Minibatch 8/8, Test Error= 0.580314598643
# Epoch 140, Minibatch 4/8, Test Error= 0.578359370222
# Epoch 140, Minibatch 8/8, Test Error= 0.579832057159
# Testing Score= 0.901663167166
# Epoch 141, Minibatch 4/8, Test Error= 0.577089091559
# Epoch 141, Minibatch 8/8, Test Error= 0.577834569256
# Epoch 142, Minibatch 4/8, Test Error= 0.574188949967
# Epoch 142, Minibatch 8/8, Test Error= 0.57659357987
# Testing Score= 0.906663167166
# Epoch 143, Minibatch 4/8, Test Error= 0.576964547342
# Epoch 143, Minibatch 8/8, Test Error= 0.576709569256
# Epoch 144, Minibatch 4/8, Test Error= 0.575862038459
# Epoch 144, Minibatch 8/8, Test Error= 0.576002054869
# Testing Score= 0.908263167166
# Epoch 145, Minibatch 4/8, Test Error= 0.573723078955
# Epoch 145, Minibatch 8/8, Test Error= 0.57637078231
# Epoch 146, Minibatch 4/8, Test Error= 0.574216064927
# Epoch 146, Minibatch 8/8, Test Error= 0.573890678807
# Testing Score= 0.916963167166
# Epoch 147, Minibatch 4/8, Test Error= 0.571258040983
# Epoch 147, Minibatch 8/8, Test Error= 0.574785222949
# Epoch 148, Minibatch 4/8, Test Error= 0.574445078699
# Epoch 148, Minibatch 8/8, Test Error= 0.572852829194
# Testing Score= 0.914763167166
# Epoch 149, Minibatch 4/8, Test Error= 0.572363949967
# Epoch 149, Minibatch 8/8, Test Error= 0.571848734033
# Epoch 150, Minibatch 4/8, Test Error= 0.572108988055
# Epoch 150, Minibatch 8/8, Test Error= 0.574484569256
# Testing Score= 0.916263167166
# Epoch 151, Minibatch 4/8, Test Error= 0.571873078955
# Epoch 151, Minibatch 8/8, Test Error= 0.572916646861
# Epoch 152, Minibatch 4/8, Test Error= 0.574987622644
# Epoch 152, Minibatch 8/8, Test Error= 0.574034569256
# Testing Score= 0.918663167166
# Epoch 153, Minibatch 4/8, Test Error= 0.571747005032
# Epoch 153, Minibatch 8/8, Test Error= 0.573660216796
# Epoch 154, Minibatch 4/8, Test Error= 0.570416266163
# Epoch 154, Minibatch 8/8, Test Error= 0.572957595887
# Testing Score= 0.917863167166
# Epoch 155, Minibatch 4/8, Test Error= 0.570700746523
# Epoch 155, Minibatch 8/8, Test Error= 0.572559569256
# Epoch 156, Minibatch 4/8, Test Error= 0.572292289787
# Epoch 156, Minibatch 8/8, Test Error= 0.57252078231
# Testing Score= 0.921163167166
# Epoch 157, Minibatch 4/8, Test Error= 0.572167289787
# Epoch 157, Minibatch 8/8, Test Error= 0.571879807777
# Epoch 158, Minibatch 4/8, Test Error= 0.571274320425
# Epoch 158, Minibatch 8/8, Test Error= 0.570529291207
# Testing Score= 0.919463167166
# Epoch 159, Minibatch 4/8, Test Error= 0.571814547342
# Epoch 159, Minibatch 8/8, Test Error= 0.571159912082
# Epoch 160, Minibatch 4/8, Test Error= 0.568975746523
# Epoch 160, Minibatch 8/8, Test Error= 0.56917801182
# Testing Score= 0.924563167166
# Epoch 161, Minibatch 4/8, Test Error= 0.568764974394
# Epoch 161, Minibatch 8/8, Test Error= 0.569069222632
# Epoch 162, Minibatch 4/8, Test Error= 0.568065923336
# Epoch 162, Minibatch 8/8, Test Error= 0.569619105323
# Testing Score= 0.916363167166
# Epoch 163, Minibatch 4/8, Test Error= 0.569701134975
# Epoch 163, Minibatch 8/8, Test Error= 0.570009912082
# Epoch 164, Minibatch 4/8, Test Error= 0.568209981765
# Epoch 164, Minibatch 8/8, Test Error= 0.570159912082
# Testing Score= 0.922363167166
# Epoch 165, Minibatch 4/8, Test Error= 0.566220837507
# Epoch 165, Minibatch 8/8, Test Error= 0.569859912082
# Epoch 166, Minibatch 4/8, Test Error= 0.567073078955
# Epoch 166, Minibatch 8/8, Test Error= 0.567879291207
# Testing Score= 0.925463167166
# Epoch 167, Minibatch 4/8, Test Error= 0.569331476045
# Epoch 167, Minibatch 8/8, Test Error= 0.567787792567
# Epoch 168, Minibatch 4/8, Test Error= 0.567198078955
# Epoch 168, Minibatch 8/8, Test Error= 0.566968078152
# Testing Score= 0.925763167166
# Epoch 169, Minibatch 4/8, Test Error= 0.568749320425
# Epoch 169, Minibatch 8/8, Test Error= 0.568108828828
# Epoch 170, Minibatch 4/8, Test Error= 0.567249099973
# Epoch 170, Minibatch 8/8, Test Error= 0.568861367113
# Testing Score= 0.928563167166
# Epoch 171, Minibatch 4/8, Test Error= 0.565637265213
# Epoch 171, Minibatch 8/8, Test Error= 0.56884614409
# Epoch 172, Minibatch 4/8, Test Error= 0.56546797465
# Epoch 172, Minibatch 8/8, Test Error= 0.56745685546
# Testing Score= 0.928763167166
# Epoch 173, Minibatch 4/8, Test Error= 0.564773078955
# Epoch 173, Minibatch 8/8, Test Error= 0.567460216796
# Epoch 174, Minibatch 4/8, Test Error= 0.566624320425
# Epoch 174, Minibatch 8/8, Test Error= 0.566037792567
# Testing Score= 0.927063167166
# Epoch 175, Minibatch 4/8, Test Error= 0.564671105587
# Epoch 175, Minibatch 8/8, Test Error= 0.564966104784
# Epoch 176, Minibatch 4/8, Test Error= 0.564815995481
# Epoch 176, Minibatch 8/8, Test Error= 0.567732221741
# Testing Score= 0.934363167166
# Epoch 177, Minibatch 4/8, Test Error= 0.563260819031
# Epoch 177, Minibatch 8/8, Test Error= 0.563286983687
# Epoch 178, Minibatch 4/8, Test Error= 0.564187265213
# Epoch 178, Minibatch 8/8, Test Error= 0.564942683108
# Testing Score= 0.935963167166
# Epoch 179, Minibatch 4/8, Test Error= 0.563290923336
# Epoch 179, Minibatch 8/8, Test Error= 0.564478389339
# Epoch 180, Minibatch 4/8, Test Error= 0.562898078955
# Epoch 180, Minibatch 8/8, Test Error= 0.564058493644
# Testing Score= 0.934963167166
# Epoch 181, Minibatch 4/8, Test Error= 0.563935291845
# Epoch 181, Minibatch 8/8, Test Error= 0.564008493644
# Epoch 182, Minibatch 4/8, Test Error= 0.563988949967
# Epoch 182, Minibatch 8/8, Test Error= 0.564916789128
# Testing Score= 0.938663167166
# Epoch 183, Minibatch 4/8, Test Error= 0.563061840048
# Epoch 183, Minibatch 8/8, Test Error= 0.562659811684
# Epoch 184, Minibatch 4/8, Test Error= 0.563421783777
# Epoch 184, Minibatch 8/8, Test Error= 0.562169745351
# Testing Score= 0.940563167166
# Epoch 185, Minibatch 4/8, Test Error= 0.563687901404
# Epoch 185, Minibatch 8/8, Test Error= 0.565184393744
# Epoch 186, Minibatch 4/8, Test Error= 0.561965923336
# Epoch 186, Minibatch 8/8, Test Error= 0.562191388599
# Testing Score= 0.943863167166
# Epoch 187, Minibatch 4/8, Test Error= 0.562373757146
# Epoch 187, Minibatch 8/8, Test Error= 0.563543762496
# Epoch 188, Minibatch 4/8, Test Error= 0.563522051265
# Epoch 188, Minibatch 8/8, Test Error= 0.560952118105
# Testing Score= 0.946563167166
# Epoch 189, Minibatch 4/8, Test Error= 0.563492289787
# Epoch 189, Minibatch 8/8, Test Error= 0.562109131817
# Epoch 190, Minibatch 4/8, Test Error= 0.561798757146
# Epoch 190, Minibatch 8/8, Test Error= 0.562618762496
# Testing Score= 0.946363167166
# Epoch 191, Minibatch 4/8, Test Error= 0.561712901404
# Epoch 191, Minibatch 8/8, Test Error= 0.561775227176
# Epoch 192, Minibatch 4/8, Test Error= 0.561373757146
# Epoch 192, Minibatch 8/8, Test Error= 0.562714642022
# Testing Score= 0.948163167166
# Epoch 193, Minibatch 4/8, Test Error= 0.561439874772
# Epoch 193, Minibatch 8/8, Test Error= 0.560401038452
# Epoch 194, Minibatch 4/8, Test Error= 0.559546190767
# Epoch 194, Minibatch 8/8, Test Error= 0.561100227176
# Testing Score= 0.948663167166
# Epoch 195, Minibatch 4/8, Test Error= 0.562412922277
# Epoch 195, Minibatch 8/8, Test Error= 0.559186205805
# Epoch 196, Minibatch 4/8, Test Error= 0.55896697595
# Epoch 196, Minibatch 8/8, Test Error= 0.561787319885
# Testing Score= 0.952763167166
# Epoch 197, Minibatch 4/8, Test Error= 0.559548078955
# Epoch 197, Minibatch 8/8, Test Error= 0.560883493644
# Epoch 198, Minibatch 4/8, Test Error= 0.559923078955
# Epoch 198, Minibatch 8/8, Test Error= 0.56202424432
# Testing Score= 0.951863167166
# Epoch 199, Minibatch 4/8, Test Error= 0.560474246787
# Epoch 199, Minibatch 8/8, Test Error= 0.55787636606
# Epoch 200, Minibatch 4/8, Test Error= 0.558740923336
# Epoch 200, Minibatch 8/8, Test Error= 0.561919140015
# Testing Score= 0.954563167166
# Epoch 201, Minibatch 4/8, Test Error= 0.558794217399
# Epoch 201, Minibatch 8/8, Test Error= 0.560383493644
# Epoch 202, Minibatch 4/8, Test Error= 0.557172311476
# Epoch 202, Minibatch 8/8, Test Error= 0.558458369409
# Testing Score= 0.956263167166
# Epoch 203, Minibatch 4/8, Test Error= 0.558335819031
# Epoch 203, Minibatch 8/8, Test Error= 0.557402420067
# Epoch 204, Minibatch 4/8, Test Error= 0.560028108343
# Epoch 204, Minibatch 8/8, Test Error= 0.56049924432
# Testing Score= 0.958863167166
# Epoch 205, Minibatch 4/8, Test Error= 0.556935819031
# Epoch 205, Minibatch 8/8, Test Error= 0.55997424432
# Epoch 206, Minibatch 4/8, Test Error= 0.555870837507
# Epoch 206, Minibatch 8/8, Test Error= 0.559527053414
# Testing Score= 0.958863167166
# Epoch 207, Minibatch 4/8, Test Error= 0.559478108343
# Epoch 207, Minibatch 8/8, Test Error= 0.557489222749
# Epoch 208, Minibatch 4/8, Test Error= 0.554815155857
# Epoch 208, Minibatch 8/8, Test Error= 0.557825227176
# Testing Score= 0.960963167166
# Epoch 209, Minibatch 4/8, Test Error= 0.556285819031
# Epoch 209, Minibatch 8/8, Test Error= 0.55877424432
# Epoch 210, Minibatch 4/8, Test Error= 0.559387190296
# Epoch 210, Minibatch 8/8, Test Error= 0.557046566727
# Testing Score= 0.958563167166
# Epoch 211, Minibatch 4/8, Test Error= 0.555915923336
# Epoch 211, Minibatch 8/8, Test Error= 0.556226375223
# Epoch 212, Minibatch 4/8, Test Error= 0.556763949967
# Epoch 212, Minibatch 8/8, Test Error= 0.557425227176
# Testing Score= 0.961663167166
# Epoch 213, Minibatch 4/8, Test Error= 0.555650952667
# Epoch 213, Minibatch 8/8, Test Error= 0.556312230965
# Epoch 214, Minibatch 4/8, Test Error= 0.555273078955
# Epoch 214, Minibatch 8/8, Test Error= 0.554274392692
# Testing Score= 0.961763167166
# Epoch 215, Minibatch 4/8, Test Error= 0.553292044045
# Epoch 215, Minibatch 8/8, Test Error= 0.556328822196
# Epoch 216, Minibatch 4/8, Test Error= 0.554848078955
# Epoch 216, Minibatch 8/8, Test Error= 0.554690447812
# Testing Score= 0.965563167166
# Epoch 217, Minibatch 4/8, Test Error= 0.553988145288
# Epoch 217, Minibatch 8/8, Test Error= 0.555489222749
# Epoch 218, Minibatch 4/8, Test Error= 0.555452547385
# Epoch 218, Minibatch 8/8, Test Error= 0.555239222749
# Testing Score= 0.968963167166
# Epoch 219, Minibatch 4/8, Test Error= 0.553570837507
# Epoch 219, Minibatch 8/8, Test Error= 0.555199487035
# Epoch 220, Minibatch 4/8, Test Error= 0.554198078955
# Epoch 220, Minibatch 8/8, Test Error= 0.556790709739
# Testing Score= 0.967163167166
# Epoch 221, Minibatch 4/8, Test Error= 0.557128108343
# Epoch 221, Minibatch 8/8, Test Error= 0.55674924432
# Epoch 222, Minibatch 4/8, Test Error= 0.553590923336
# Epoch 222, Minibatch 8/8, Test Error= 0.55461771279
# Testing Score= 0.969563167166
# Epoch 223, Minibatch 4/8, Test Error= 0.553933165613
# Epoch 223, Minibatch 8/8, Test Error= 0.554782448504
# Epoch 224, Minibatch 4/8, Test Error= 0.553980109594
# Epoch 224, Minibatch 8/8, Test Error= 0.555033369409
# Testing Score= 0.974163167166
# Epoch 225, Minibatch 4/8, Test Error= 0.553535291845
# Epoch 225, Minibatch 8/8, Test Error= 0.553898454915
# Epoch 226, Minibatch 4/8, Test Error= 0.551837724937
# Epoch 226, Minibatch 8/8, Test Error= 0.554257448504
# Testing Score= 0.972963167166
# Epoch 227, Minibatch 4/8, Test Error= 0.552388949967
# Epoch 227, Minibatch 8/8, Test Error= 0.554008369409
# Epoch 228, Minibatch 4/8, Test Error= 0.552363949967
# Epoch 228, Minibatch 8/8, Test Error= 0.55475341321
# Testing Score= 0.977463167166
# Epoch 229, Minibatch 4/8, Test Error= 0.550720159316
# Epoch 229, Minibatch 8/8, Test Error= 0.556606201498
# Epoch 230, Minibatch 4/8, Test Error= 0.551320159316
# Epoch 230, Minibatch 8/8, Test Error= 0.551327600286
# Testing Score= 0.978063167166
# Epoch 231, Minibatch 4/8, Test Error= 0.554376134975
# Epoch 231, Minibatch 8/8, Test Error= 0.554926008273
# Epoch 232, Minibatch 4/8, Test Error= 0.552154136033
# Epoch 232, Minibatch 8/8, Test Error= 0.552705560315
# Testing Score= 0.978563167166
# Epoch 233, Minibatch 4/8, Test Error= 0.553733165613
# Epoch 233, Minibatch 8/8, Test Error= 0.552635257597
# Epoch 234, Minibatch 4/8, Test Error= 0.549923033028
# Epoch 234, Minibatch 8/8, Test Error= 0.552980301398
# Testing Score= 0.982163167166
# Epoch 235, Minibatch 4/8, Test Error= 0.551929136033
# Epoch 235, Minibatch 8/8, Test Error= 0.552307448504
# Epoch 236, Minibatch 4/8, Test Error= 0.551363949967
# Epoch 236, Minibatch 8/8, Test Error= 0.553203790441
# Testing Score= 0.984263167166
# Epoch 237, Minibatch 4/8, Test Error= 0.550904136033
# Epoch 237, Minibatch 8/8, Test Error= 0.553658463466
# Epoch 238, Minibatch 4/8, Test Error= 0.550788949967
# Epoch 238, Minibatch 8/8, Test Error= 0.552651902253
# Testing Score= 0.982163167166
# Epoch 239, Minibatch 4/8, Test Error= 0.549895685236
# Epoch 239, Minibatch 8/8, Test Error= 0.553502981641
# Epoch 240, Minibatch 4/8, Test Error= 0.550546105587
# Epoch 240, Minibatch 8/8, Test Error= 0.552684157722
# Testing Score= 0.985863167166
# Epoch 241, Minibatch 4/8, Test Error= 0.548775153557
# Epoch 241, Minibatch 8/8, Test Error= 0.551532448504
# Epoch 242, Minibatch 4/8, Test Error= 0.548620159316
# Epoch 242, Minibatch 8/8, Test Error= 0.55079271279
# Testing Score= 0.985863167166
# Epoch 243, Minibatch 4/8, Test Error= 0.552276134975
# Epoch 243, Minibatch 8/8, Test Error= 0.551937517493
# Epoch 244, Minibatch 4/8, Test Error= 0.549021980414
# Epoch 244, Minibatch 8/8, Test Error= 0.552208463466
# Testing Score= 0.987363167166
# Epoch 245, Minibatch 4/8, Test Error= 0.549388949967
# Epoch 245, Minibatch 8/8, Test Error= 0.553136371528
# Epoch 246, Minibatch 4/8, Test Error= 0.548221980414
# Epoch 246, Minibatch 8/8, Test Error= 0.551958463466
# Testing Score= 0.990463167166
# Epoch 247, Minibatch 4/8, Test Error= 0.550077162665
# Epoch 247, Minibatch 8/8, Test Error= 0.550035257597
# Epoch 248, Minibatch 4/8, Test Error= 0.547071980414
# Epoch 248, Minibatch 8/8, Test Error= 0.549582448504
# Testing Score= 0.989863167166
# Epoch 249, Minibatch 4/8, Test Error= 0.548654136033
# Epoch 249, Minibatch 8/8, Test Error= 0.551351008273
# Epoch 250, Minibatch 4/8, Test Error= 0.545844738965
# Epoch 250, Minibatch 8/8, Test Error= 0.548907448504
# Testing Score= 0.990063167166
# Epoch 251, Minibatch 4/8, Test Error= 0.546454322447
# Epoch 251, Minibatch 8/8, Test Error= 0.551994541117
# Epoch 252, Minibatch 4/8, Test Error= 0.549201524822
# Epoch 252, Minibatch 8/8, Test Error= 0.551990233085
# Testing Score= 0.992963167166
# Epoch 253, Minibatch 4/8, Test Error= 0.546820007046
# Epoch 253, Minibatch 8/8, Test Error= 0.549758112581
# Epoch 254, Minibatch 4/8, Test Error= 0.546838366254
# Epoch 254, Minibatch 8/8, Test Error= 0.547861132474
# Testing Score= 0.995163167166
# Epoch 255, Minibatch 4/8, Test Error= 0.547324112791
# Epoch 255, Minibatch 8/8, Test Error= 0.549008350306
# Epoch 256, Minibatch 4/8, Test Error= 0.545821980414
# Epoch 256, Minibatch 8/8, Test Error= 0.54929137905
# Testing Score= 0.998463167166
# Epoch 257, Minibatch 4/8, Test Error= 0.545666957172
# Epoch 257, Minibatch 8/8, Test Error= 0.549906490097
# Epoch 258, Minibatch 4/8, Test Error= 0.545671980414
# Epoch 258, Minibatch 8/8, Test Error= 0.547448721083
# Testing Score= 0.999363167166
# Epoch 259, Minibatch 4/8, Test Error= 0.544521193152
# Epoch 259, Minibatch 8/8, Test Error= 0.550669541117
# Epoch 260, Minibatch 4/8, Test Error= 0.545788366254
# Epoch 260, Minibatch 8/8, Test Error= 0.54894121594
# Testing Score= 0.997863167166
# Epoch 261, Minibatch 4/8, Test Error= 0.546349112791
# Epoch 261, Minibatch 8/8, Test Error= 0.54829137905
# Epoch 262, Minibatch 4/8, Test Error= 0.544968322291
# Epoch 262, Minibatch 8/8, Test Error= 0.54829137905
# Testing Score= 0.996509871178
# Epoch 263, Minibatch 4/8, Test Error= 0.543559236618
# Epoch 263, Minibatch 8/8, Test Error= 0.548438096204
# Epoch 264, Minibatch 4/8, Test Error= 0.547391957172
# Epoch 264, Minibatch 8/8, Test Error= 0.54784137905
# Testing Score= 1.00080987118
# Epoch 265, Minibatch 4/8, Test Error= 0.547149112791
# Epoch 265, Minibatch 8/8, Test Error= 0.547758112581
# Epoch 266, Minibatch 4/8, Test Error= 0.544338366254
# Epoch 266, Minibatch 8/8, Test Error= 0.547814327752
# Testing Score= 1.00500987118
# Epoch 267, Minibatch 4/8, Test Error= 0.544416957172
# Epoch 267, Minibatch 8/8, Test Error= 0.545531597303
# Epoch 268, Minibatch 4/8, Test Error= 0.545213366254
# Epoch 268, Minibatch 8/8, Test Error= 0.549315233085
# Testing Score= 1.00610987118
# Epoch 269, Minibatch 4/8, Test Error= 0.543870007046
# Epoch 269, Minibatch 8/8, Test Error= 0.546858112581
# Epoch 270, Minibatch 4/8, Test Error= 0.545548232816
# Epoch 270, Minibatch 8/8, Test Error= 0.545748520992
# Testing Score= 1.00920987118
# Epoch 271, Minibatch 4/8, Test Error= 0.545324112791
# Epoch 271, Minibatch 8/8, Test Error= 0.545762211862
# Epoch 272, Minibatch 4/8, Test Error= 0.544389044445
# Epoch 272, Minibatch 8/8, Test Error= 0.547721425918
# Testing Score= 1.00940987118
# Epoch 273, Minibatch 4/8, Test Error= 0.544089179124
# Epoch 273, Minibatch 8/8, Test Error= 0.547177981641
# Epoch 274, Minibatch 4/8, Test Error= 0.543835342823
# Epoch 274, Minibatch 8/8, Test Error= 0.54599137905
# Testing Score= 1.01210987118
# Epoch 275, Minibatch 4/8, Test Error= 0.543373180188
# Epoch 275, Minibatch 8/8, Test Error= 0.54599137905
# Epoch 276, Minibatch 4/8, Test Error= 0.541534454424
# Epoch 276, Minibatch 8/8, Test Error= 0.548040233085
# Testing Score= 1.01260987118
# Epoch 277, Minibatch 4/8, Test Error= 0.543914044445
# Epoch 277, Minibatch 8/8, Test Error= 0.546796425918
# Epoch 278, Minibatch 4/8, Test Error= 0.543812231011
# Epoch 278, Minibatch 8/8, Test Error= 0.547931985719
# Testing Score= 1.01720987118
# Epoch 279, Minibatch 4/8, Test Error= 0.54301771563
# Epoch 279, Minibatch 8/8, Test Error= 0.544560323674
# Epoch 280, Minibatch 4/8, Test Error= 0.540269304964
# Epoch 280, Minibatch 8/8, Test Error= 0.54531637905
# Testing Score= 1.01640987118
# Epoch 281, Minibatch 4/8, Test Error= 0.542768944503
# Epoch 281, Minibatch 8/8, Test Error= 0.546596425918
# Epoch 282, Minibatch 4/8, Test Error= 0.542518983105
# Epoch 282, Minibatch 8/8, Test Error= 0.546637484296
# Testing Score= 1.02040987118
# Epoch 283, Minibatch 4/8, Test Error= 0.542442009799
# Epoch 283, Minibatch 8/8, Test Error= 0.54714067956
# Epoch 284, Minibatch 4/8, Test Error= 0.542868944503
# Epoch 284, Minibatch 8/8, Test Error= 0.543148482391
# Testing Score= 1.01930987118
# Epoch 285, Minibatch 4/8, Test Error= 0.541518944503
# Epoch 285, Minibatch 8/8, Test Error= 0.544621714517
# Epoch 286, Minibatch 4/8, Test Error= 0.541405757332
# Epoch 286, Minibatch 8/8, Test Error= 0.547774587985
# Testing Score= 1.02460987118
# Epoch 287, Minibatch 4/8, Test Error= 0.540800718101
# Epoch 287, Minibatch 8/8, Test Error= 0.542873482391
# Epoch 288, Minibatch 4/8, Test Error= 0.543466420452
# Epoch 288, Minibatch 8/8, Test Error= 0.547174587985
# Testing Score= 1.02600987118
# Epoch 289, Minibatch 4/8, Test Error= 0.542249562009
# Epoch 289, Minibatch 8/8, Test Error= 0.542741664262
# Epoch 290, Minibatch 4/8, Test Error= 0.54449295607
# Epoch 290, Minibatch 8/8, Test Error= 0.541547189338
# Testing Score= 1.02500987118
# Epoch 291, Minibatch 4/8, Test Error= 0.542268393821
# Epoch 291, Minibatch 8/8, Test Error= 0.547024587985
# Epoch 292, Minibatch 4/8, Test Error= 0.542574600611
# Epoch 292, Minibatch 8/8, Test Error= 0.54416428915
# Testing Score= 1.02850987118
# Epoch 293, Minibatch 4/8, Test Error= 0.541519919163
# Epoch 293, Minibatch 8/8, Test Error= 0.543959934758
# Epoch 294, Minibatch 4/8, Test Error= 0.54134623505
# Epoch 294, Minibatch 8/8, Test Error= 0.54413304657
# Testing Score= 1.03300987118
# Epoch 295, Minibatch 4/8, Test Error= 0.541352124662
# Epoch 295, Minibatch 8/8, Test Error= 0.542821594203
# Epoch 296, Minibatch 4/8, Test Error= 0.540487117655
# Epoch 296, Minibatch 8/8, Test Error= 0.546097606582
# Testing Score= 1.03230987118
# Epoch 297, Minibatch 4/8, Test Error= 0.54215401285
# Epoch 297, Minibatch 8/8, Test Error= 0.547336338331
# Epoch 298, Minibatch 4/8, Test Error= 0.540226261913
# Epoch 298, Minibatch 8/8, Test Error= 0.543300001091
# Testing Score= 1.03270987118
# Epoch 299, Minibatch 4/8, Test Error= 0.543244622694
# Epoch 299, Minibatch 8/8, Test Error= 0.543671714517
# Epoch 300, Minibatch 4/8, Test Error= 0.54217123505
# Epoch 300, Minibatch 8/8, Test Error= 0.545871064435
# Testing Score= 1.03300987118
# Epoch 301, Minibatch 4/8, Test Error= 0.543069622694
# Epoch 301, Minibatch 8/8, Test Error= 0.544869252459
# Epoch 302, Minibatch 4/8, Test Error= 0.541064947564
# Epoch 302, Minibatch 8/8, Test Error= 0.542353529259
# Testing Score= 1.03610987118
# Epoch 303, Minibatch 4/8, Test Error= 0.539598809064
# Epoch 303, Minibatch 8/8, Test Error= 0.542203529259
# Epoch 304, Minibatch 4/8, Test Error= 0.542727840151
# Epoch 304, Minibatch 8/8, Test Error= 0.544879184058
# Testing Score= 1.03610987118
# Epoch 305, Minibatch 4/8, Test Error= 0.540792164524
# Epoch 305, Minibatch 8/8, Test Error= 0.546437032587
# Epoch 306, Minibatch 4/8, Test Error= 0.54321795607
# Epoch 306, Minibatch 8/8, Test Error= 0.54359244783
# Testing Score= 1.04440987118
# Epoch 307, Minibatch 4/8, Test Error= 0.542019622694
# Epoch 307, Minibatch 8/8, Test Error= 0.544833028509
# Epoch 308, Minibatch 4/8, Test Error= 0.540884995771
# Epoch 308, Minibatch 8/8, Test Error= 0.542184934758
# Testing Score= 1.04320987118
# Epoch 309, Minibatch 4/8, Test Error= 0.539748085417
# Epoch 309, Minibatch 8/8, Test Error= 0.540991219144
# Epoch 310, Minibatch 4/8, Test Error= 0.542694929438
# Epoch 310, Minibatch 8/8, Test Error= 0.544725089891
# Testing Score= 1.04380987118
# Epoch 311, Minibatch 4/8, Test Error= 0.539604854408
# Epoch 311, Minibatch 8/8, Test Error= 0.542734322229
# Epoch 312, Minibatch 4/8, Test Error= 0.539298939993
# Epoch 312, Minibatch 8/8, Test Error= 0.54193296139
# Testing Score= 1.04420987118
# Epoch 313, Minibatch 4/8, Test Error= 0.541144622694
# Epoch 313, Minibatch 8/8, Test Error= 0.541185772892
# Epoch 314, Minibatch 4/8, Test Error= 0.538304962036
# Epoch 314, Minibatch 8/8, Test Error= 0.541284934758
# Testing Score= 1.04670987118
# Epoch 315, Minibatch 4/8, Test Error= 0.53728493724
# Epoch 315, Minibatch 8/8, Test Error= 0.54110796139
# Epoch 316, Minibatch 4/8, Test Error= 0.540317299202
# Epoch 316, Minibatch 8/8, Test Error= 0.545299414738
# Testing Score= 1.04790987118
# Epoch 317, Minibatch 4/8, Test Error= 0.538381147347
# Epoch 317, Minibatch 8/8, Test Error= 0.541284934758
# Epoch 318, Minibatch 4/8, Test Error= 0.541576417301
# Epoch 318, Minibatch 8/8, Test Error= 0.544579768203
# Testing Score= 1.04840987118
# Epoch 319, Minibatch 4/8, Test Error= 0.541986488914
# Epoch 319, Minibatch 8/8, Test Error= 0.542626186403
# Epoch 320, Minibatch 4/8, Test Error= 0.540698939993
# Epoch 320, Minibatch 8/8, Test Error= 0.542114981627
# Testing Score= 1.05210987118
# Epoch 321, Minibatch 4/8, Test Error= 0.540088109641
# Epoch 321, Minibatch 8/8, Test Error= 0.541506232526
# Epoch 322, Minibatch 4/8, Test Error= 0.538962117655
# Epoch 322, Minibatch 8/8, Test Error= 0.539891081013
# Testing Score= 1.05090987118
# Epoch 323, Minibatch 4/8, Test Error= 0.540767663041
# Epoch 323, Minibatch 8/8, Test Error= 0.544229733229
# Epoch 324, Minibatch 4/8, Test Error= 0.54070126054
# Epoch 324, Minibatch 8/8, Test Error= 0.542515816743
# Testing Score= 1.05280987118
# Epoch 325, Minibatch 4/8, Test Error= 0.540969622694
# Epoch 325, Minibatch 8/8, Test Error= 0.543442364271
# Epoch 326, Minibatch 4/8, Test Error= 0.543361692724
# Epoch 326, Minibatch 8/8, Test Error= 0.54390140203
# Testing Score= 1.05890987118
# Epoch 327, Minibatch 4/8, Test Error= 0.538287178688
# Epoch 327, Minibatch 8/8, Test Error= 0.539125858398
# Epoch 328, Minibatch 4/8, Test Error= 0.540369622694
# Epoch 328, Minibatch 8/8, Test Error= 0.544249395635
# Testing Score= 1.05490987118
# Epoch 329, Minibatch 4/8, Test Error= 0.54170469104
# Epoch 329, Minibatch 8/8, Test Error= 0.544128736878
# Epoch 330, Minibatch 4/8, Test Error= 0.540030960934
# Epoch 330, Minibatch 8/8, Test Error= 0.540506073202
# Testing Score= 1.05970987118
# Epoch 331, Minibatch 4/8, Test Error= 0.53668493724
# Epoch 331, Minibatch 8/8, Test Error= 0.540009934758
# Epoch 332, Minibatch 4/8, Test Error= 0.542740820717
# Epoch 332, Minibatch 8/8, Test Error= 0.54061112007
# Testing Score= 1.06220987118
# Epoch 333, Minibatch 4/8, Test Error= 0.540590899524
# Epoch 333, Minibatch 8/8, Test Error= 0.539479758556
# Epoch 334, Minibatch 4/8, Test Error= 0.541586296564
# Epoch 334, Minibatch 8/8, Test Error= 0.542407821855
# Testing Score= 1.05990987118
# Epoch 335, Minibatch 4/8, Test Error= 0.539749890014
# Epoch 335, Minibatch 8/8, Test Error= 0.544262003347
# Epoch 336, Minibatch 4/8, Test Error= 0.538773085417
# Epoch 336, Minibatch 8/8, Test Error= 0.538815927672
# Testing Score= 1.06660987118
# Epoch 337, Minibatch 4/8, Test Error= 0.539137984729
# Epoch 337, Minibatch 8/8, Test Error= 0.54071112007
# Epoch 338, Minibatch 4/8, Test Error= 0.539823053075
# Epoch 338, Minibatch 8/8, Test Error= 0.54105105576
# Testing Score= 1.06440987118
# Epoch 339, Minibatch 4/8, Test Error= 0.538393683224
# Epoch 339, Minibatch 8/8, Test Error= 0.542762484296
# Epoch 340, Minibatch 4/8, Test Error= 0.538729333294
# Epoch 340, Minibatch 8/8, Test Error= 0.545388192046
# Testing Score= 1.06310987118
# Epoch 341, Minibatch 4/8, Test Error= 0.542409719356
# Epoch 341, Minibatch 8/8, Test Error= 0.541862452517
# Epoch 342, Minibatch 4/8, Test Error= 0.539507627358
# Epoch 342, Minibatch 8/8, Test Error= 0.541937452517
# Testing Score= 1.06680987118
# Epoch 343, Minibatch 4/8, Test Error= 0.540133416159
# Epoch 343, Minibatch 8/8, Test Error= 0.544778569474
# Epoch 344, Minibatch 4/8, Test Error= 0.539872925225
# Epoch 344, Minibatch 8/8, Test Error= 0.542725413811
# Testing Score= 1.06900987118
# Epoch 345, Minibatch 4/8, Test Error= 0.536621314767
# Epoch 345, Minibatch 8/8, Test Error= 0.54083612007
# Epoch 346, Minibatch 4/8, Test Error= 0.538926282787
# Epoch 346, Minibatch 8/8, Test Error= 0.539160799376
# Testing Score= 1.07190987118
# Epoch 347, Minibatch 4/8, Test Error= 0.538942649325
# Epoch 347, Minibatch 8/8, Test Error= 0.543724395635
# Epoch 348, Minibatch 4/8, Test Error= 0.539974669562
# Epoch 348, Minibatch 8/8, Test Error= 0.541434283132
# Testing Score= 1.07180987118
# Epoch 349, Minibatch 4/8, Test Error= 0.541908128378
# Epoch 349, Minibatch 8/8, Test Error= 0.54305176351
# Epoch 350, Minibatch 4/8, Test Error= 0.538334995771
# Epoch 350, Minibatch 8/8, Test Error= 0.543076111303
# Testing Score= 1.07210987118
# Epoch 351, Minibatch 4/8, Test Error= 0.539024669562
# Epoch 351, Minibatch 8/8, Test Error= 0.541778778037
# Epoch 352, Minibatch 4/8, Test Error= 0.538074529113
# Epoch 352, Minibatch 8/8, Test Error= 0.538605435298
# Testing Score= 1.07430987118
# Epoch 353, Minibatch 4/8, Test Error= 0.541171921099
# Epoch 353, Minibatch 8/8, Test Error= 0.542397507447
# Epoch 354, Minibatch 4/8, Test Error= 0.540307014413
# Epoch 354, Minibatch 8/8, Test Error= 0.541488928555
# Testing Score= 1.07880987118
# Epoch 355, Minibatch 4/8, Test Error= 0.537314195298
# Epoch 355, Minibatch 8/8, Test Error= 0.537490927672
# Epoch 356, Minibatch 4/8, Test Error= 0.53956811392
# Epoch 356, Minibatch 8/8, Test Error= 0.538216219144
# Testing Score= 1.07790987118
# Epoch 357, Minibatch 4/8, Test Error= 0.538078830773
# Epoch 357, Minibatch 8/8, Test Error= 0.53958612007
# Epoch 358, Minibatch 4/8, Test Error= 0.53874728757
# Epoch 358, Minibatch 8/8, Test Error= 0.540072179443
# Testing Score= 1.07600987118
# Epoch 359, Minibatch 4/8, Test Error= 0.54086994773
# Epoch 359, Minibatch 8/8, Test Error= 0.541510801832
# Epoch 360, Minibatch 4/8, Test Error= 0.537883068981
# Epoch 360, Minibatch 8/8, Test Error= 0.54049157953
# Testing Score= 1.07550987118
# Epoch 361, Minibatch 4/8, Test Error= 0.54006811392
# Epoch 361, Minibatch 8/8, Test Error= 0.542178736878
# Epoch 362, Minibatch 4/8, Test Error= 0.537632993829
# Epoch 362, Minibatch 8/8, Test Error= 0.539990816743
# Testing Score= 1.08100987118
# Epoch 363, Minibatch 4/8, Test Error= 0.540508128378
# Epoch 363, Minibatch 8/8, Test Error= 0.539890816743
# Epoch 364, Minibatch 4/8, Test Error= 0.538099669562
# Epoch 364, Minibatch 8/8, Test Error= 0.540132394944
# Testing Score= 1.08530987118
# Epoch 365, Minibatch 4/8, Test Error= 0.539708128378
# Epoch 365, Minibatch 8/8, Test Error= 0.539690816743
# Epoch 366, Minibatch 4/8, Test Error= 0.540071921099
# Epoch 366, Minibatch 8/8, Test Error= 0.544090165414
# Testing Score= 1.08600987118
# Epoch 367, Minibatch 4/8, Test Error= 0.538904307801
# Epoch 367, Minibatch 8/8, Test Error= 0.536815927672
# Epoch 368, Minibatch 4/8, Test Error= 0.538248274949
# Epoch 368, Minibatch 8/8, Test Error= 0.540867499385
# Testing Score= 1.08640987118
# Epoch 369, Minibatch 4/8, Test Error= 0.53846602928
# Epoch 369, Minibatch 8/8, Test Error= 0.53923612007
# Epoch 370, Minibatch 4/8, Test Error= 0.538469910724
# Epoch 370, Minibatch 8/8, Test Error= 0.544115165414
# Testing Score= 1.08520987118
# Epoch 371, Minibatch 4/8, Test Error= 0.539335635297
# Epoch 371, Minibatch 8/8, Test Error= 0.540063928555
# Epoch 372, Minibatch 4/8, Test Error= 0.536214195298
# Epoch 372, Minibatch 8/8, Test Error= 0.536528823983
# Testing Score= 1.09030987118
# Epoch 373, Minibatch 4/8, Test Error= 0.539465820717
# Epoch 373, Minibatch 8/8, Test Error= 0.538722179443
# Epoch 374, Minibatch 4/8, Test Error= 0.535093322323
# Epoch 374, Minibatch 8/8, Test Error= 0.538402332368
# Testing Score= 1.08700987118
# Epoch 375, Minibatch 4/8, Test Error= 0.540707355916
# Epoch 375, Minibatch 8/8, Test Error= 0.53893612007
# Epoch 376, Minibatch 4/8, Test Error= 0.536028132285
# Epoch 376, Minibatch 8/8, Test Error= 0.536605712171
# Testing Score= 1.08890987118
# Epoch 377, Minibatch 4/8, Test Error= 0.534183376821
# Epoch 377, Minibatch 8/8, Test Error= 0.542328736878
# Epoch 378, Minibatch 4/8, Test Error= 0.536867663041
# Epoch 378, Minibatch 8/8, Test Error= 0.543438192046
# Testing Score= 1.08770987118
# Epoch 379, Minibatch 4/8, Test Error= 0.538219910724
# Epoch 379, Minibatch 8/8, Test Error= 0.540485510927
# Epoch 380, Minibatch 4/8, Test Error= 0.538766628174
# Epoch 380, Minibatch 8/8, Test Error= 0.542411745647
# Testing Score= 1.09180987118
# Epoch 381, Minibatch 4/8, Test Error= 0.539958128378
# Epoch 381, Minibatch 8/8, Test Error= 0.539059283132
# Epoch 382, Minibatch 4/8, Test Error= 0.535833068981
# Epoch 382, Minibatch 8/8, Test Error= 0.53936112007
# Testing Score= 1.09590987118
# Epoch 383, Minibatch 4/8, Test Error= 0.53755756448
# Epoch 383, Minibatch 8/8, Test Error= 0.536858862719
# Epoch 384, Minibatch 4/8, Test Error= 0.536656242568
# Epoch 384, Minibatch 8/8, Test Error= 0.53916112007
# Testing Score= 1.09580987118
# Epoch 385, Minibatch 4/8, Test Error= 0.537081329655
# Epoch 385, Minibatch 8/8, Test Error= 0.536534639681
# Epoch 386, Minibatch 4/8, Test Error= 0.538115024628
# Epoch 386, Minibatch 8/8, Test Error= 0.539498698143
# Testing Score= 1.09500987118
# Epoch 387, Minibatch 4/8, Test Error= 0.534343322323
# Epoch 387, Minibatch 8/8, Test Error= 0.543883616342
# Epoch 388, Minibatch 4/8, Test Error= 0.537121965768
# Epoch 388, Minibatch 8/8, Test Error= 0.540250413811
# Testing Score= 1.09720987118
# Epoch 389, Minibatch 4/8, Test Error= 0.532774688533
# Epoch 389, Minibatch 8/8, Test Error= 0.539049167572
# Epoch 390, Minibatch 4/8, Test Error= 0.535707516778
# Epoch 390, Minibatch 8/8, Test Error= 0.539917140938
# Testing Score= 1.10200987118
# Epoch 391, Minibatch 4/8, Test Error= 0.533345005586
# Epoch 391, Minibatch 8/8, Test Error= 0.53903234886
# Epoch 392, Minibatch 4/8, Test Error= 0.537741997997
# Epoch 392, Minibatch 8/8, Test Error= 0.539073698143
# Testing Score= 1.09830987118
# Epoch 393, Minibatch 4/8, Test Error= 0.53547252041
# Epoch 393, Minibatch 8/8, Test Error= 0.543908616342
# Epoch 394, Minibatch 4/8, Test Error= 0.535627381012
# Epoch 394, Minibatch 8/8, Test Error= 0.540167499385
# Testing Score= 1.10430987118
# Epoch 395, Minibatch 4/8, Test Error= 0.534549493778
# Epoch 395, Minibatch 8/8, Test Error= 0.539765437481
# Epoch 396, Minibatch 4/8, Test Error= 0.539033128378
# Epoch 396, Minibatch 8/8, Test Error= 0.537985720568
# Testing Score= 1.10210987118
# Epoch 397, Minibatch 4/8, Test Error= 0.538983541228
# Epoch 397, Minibatch 8/8, Test Error= 0.534945003113
# Epoch 398, Minibatch 4/8, Test Error= 0.534509299327
# Epoch 398, Minibatch 8/8, Test Error= 0.53801880871
# Testing Score= 1.10420987118
# Epoch 399, Minibatch 4/8, Test Error= 0.535931565812
# Epoch 399, Minibatch 8/8, Test Error= 0.542658616342
# Epoch 400, Minibatch 4/8, Test Error= 0.53218366525
# ...
# Epoch 1869, Minibatch 8/8, Test Error= 0.533634834609
# Epoch 1870, Minibatch 4/8, Test Error= 0.529439969117
# Epoch 1870, Minibatch 8/8, Test Error= 0.526663245136
# Testing Score= 1.229314842
# Epoch 1871, Minibatch 4/8, Test Error= 0.526019427227
# Epoch 1871, Minibatch 8/8, Test Error= 0.533429497014
# Epoch 1872, Minibatch 4/8, Test Error= 0.530232794068
# Epoch 1872, Minibatch 8/8, Test Error= 0.532867976121
# Testing Score= 1.222814842
# Epoch 1873, Minibatch 4/8, Test Error= 0.532088813125
# Epoch 1873, Minibatch 8/8, Test Error= 0.530906678946
# Epoch 1874, Minibatch 4/8, Test Error= 0.5279518668
# Epoch 1874, Minibatch 8/8, Test Error= 0.53863828903
# Testing Score= 1.224614842
# Epoch 1875, Minibatch 4/8, Test Error= 0.530406471814
# Epoch 1875, Minibatch 8/8, Test Error= 0.52910708803
# Epoch 1876, Minibatch 4/8, Test Error= 0.528233005619
# Epoch 1876, Minibatch 8/8, Test Error= 0.531174966601
# Testing Score= 1.225214842
# Epoch 1877, Minibatch 4/8, Test Error= 0.529651477046
# Epoch 1877, Minibatch 8/8, Test Error= 0.530651542738
# Epoch 1878, Minibatch 4/8, Test Error= 0.529163899685
# Epoch 1878, Minibatch 8/8, Test Error= 0.540324717566
# Testing Score= 1.231114842
# Epoch 1879, Minibatch 4/8, Test Error= 0.528390545042
# Epoch 1879, Minibatch 8/8, Test Error= 0.533109834609
# Epoch 1880, Minibatch 4/8, Test Error= 0.528495213088
# Epoch 1880, Minibatch 8/8, Test Error= 0.527552751793
# Testing Score= 1.226014842
# Epoch 1881, Minibatch 4/8, Test Error= 0.528829296286
# Epoch 1881, Minibatch 8/8, Test Error= 0.528867188466
# Epoch 1882, Minibatch 4/8, Test Error= 0.528405647043
# Epoch 1882, Minibatch 8/8, Test Error= 0.52786549304
# Testing Score= 1.228014842
# Epoch 1883, Minibatch 4/8, Test Error= 0.536277548415
# Epoch 1883, Minibatch 8/8, Test Error= 0.52864368397
# Epoch 1884, Minibatch 4/8, Test Error= 0.529168601542
# Epoch 1884, Minibatch 8/8, Test Error= 0.528548799506
# Testing Score= 1.232214842
# Epoch 1885, Minibatch 4/8, Test Error= 0.52927876954
# Epoch 1885, Minibatch 8/8, Test Error= 0.533759834609
# Epoch 1886, Minibatch 4/8, Test Error= 0.529009458863
# Epoch 1886, Minibatch 8/8, Test Error= 0.531113383704
# Testing Score= 1.234014842
# Epoch 1887, Minibatch 4/8, Test Error= 0.529258165006
# Epoch 1887, Minibatch 8/8, Test Error= 0.531149966601
# Epoch 1888, Minibatch 4/8, Test Error= 0.530395041612
# Epoch 1888, Minibatch 8/8, Test Error= 0.526807158157
# Testing Score= 1.223614842
# Epoch 1889, Minibatch 4/8, Test Error= 0.529139175776
# Epoch 1889, Minibatch 8/8, Test Error= 0.527221944637
# Epoch 1890, Minibatch 4/8, Test Error= 0.530756585395
# Epoch 1890, Minibatch 8/8, Test Error= 0.528873130689
# Testing Score= 1.233614842
# Epoch 1891, Minibatch 4/8, Test Error= 0.532031834667
# Epoch 1891, Minibatch 8/8, Test Error= 0.533859834609
# Epoch 1892, Minibatch 4/8, Test Error= 0.528631844293
# Epoch 1892, Minibatch 8/8, Test Error= 0.529250197281
# Testing Score= 1.232014842
# Epoch 1893, Minibatch 4/8, Test Error= 0.530821372741
# Epoch 1893, Minibatch 8/8, Test Error= 0.53863828903
# Epoch 1894, Minibatch 4/8, Test Error= 0.528558986643
# Epoch 1894, Minibatch 8/8, Test Error= 0.528517427767
# Testing Score= 1.230514842
# Epoch 1895, Minibatch 4/8, Test Error= 0.532539060449
# Epoch 1895, Minibatch 8/8, Test Error= 0.527497041619
# Epoch 1896, Minibatch 4/8, Test Error= 0.530501134219
# Epoch 1896, Minibatch 8/8, Test Error= 0.528818362222
# Testing Score= 1.228314842
# Epoch 1897, Minibatch 4/8, Test Error= 0.531699679047
# Epoch 1897, Minibatch 8/8, Test Error= 0.539999717566
# Epoch 1898, Minibatch 4/8, Test Error= 0.526155839002
# Epoch 1898, Minibatch 8/8, Test Error= 0.526913245136
# Testing Score= 1.230814842
# Epoch 1899, Minibatch 4/8, Test Error= 0.53163190483
# Epoch 1899, Minibatch 8/8, Test Error= 0.529189114043
# Epoch 1900, Minibatch 4/8, Test Error= 0.526230327248
# Epoch 1900, Minibatch 8/8, Test Error= 0.529350024038
# Testing Score= 1.228514842
# Epoch 1901, Minibatch 4/8, Test Error= 0.536782642537
# Epoch 1901, Minibatch 8/8, Test Error= 0.528505361632
# Epoch 1902, Minibatch 4/8, Test Error= 0.529949281963
# Epoch 1902, Minibatch 8/8, Test Error= 0.528094653506
# Testing Score= 1.233214842
# Epoch 1903, Minibatch 4/8, Test Error= 0.533007910278
# Epoch 1903, Minibatch 8/8, Test Error= 0.526621927327
# Epoch 1904, Minibatch 4/8, Test Error= 0.52942876954
# Epoch 1904, Minibatch 8/8, Test Error= 0.533384491782
# Testing Score= 1.231214842
# Epoch 1905, Minibatch 4/8, Test Error= 0.531899679047
# Epoch 1905, Minibatch 8/8, Test Error= 0.532821951295
# Epoch 1906, Minibatch 4/8, Test Error= 0.528214032236
# Epoch 1906, Minibatch 8/8, Test Error= 0.527206257406
# Testing Score= 1.230614842
# Epoch 1907, Minibatch 4/8, Test Error= 0.534113736199
# Epoch 1907, Minibatch 8/8, Test Error= 0.531880070906
# Epoch 1908, Minibatch 4/8, Test Error= 0.529410094545
# Epoch 1908, Minibatch 8/8, Test Error= 0.533823290825
# Testing Score= 1.232514842
# Epoch 1909, Minibatch 4/8, Test Error= 0.529597555014
# Epoch 1909, Minibatch 8/8, Test Error= 0.534937575944
# Epoch 1910, Minibatch 4/8, Test Error= 0.530281947234
# Epoch 1910, Minibatch 8/8, Test Error= 0.536858448911
# Testing Score= 1.227814842
# Epoch 1911, Minibatch 4/8, Test Error= 0.530059695045
# Epoch 1911, Minibatch 8/8, Test Error= 0.530521754065
# Epoch 1912, Minibatch 4/8, Test Error= 0.532342337015
# Epoch 1912, Minibatch 8/8, Test Error= 0.524939391101
# Testing Score= 1.230414842
# Epoch 1913, Minibatch 4/8, Test Error= 0.529599281963
# Epoch 1913, Minibatch 8/8, Test Error= 0.527138245136
# Epoch 1914, Minibatch 4/8, Test Error= 0.528665339194
# Epoch 1914, Minibatch 8/8, Test Error= 0.536681875544
# Testing Score= 1.227914842
# Epoch 1915, Minibatch 4/8, Test Error= 0.530601477046
# Epoch 1915, Minibatch 8/8, Test Error= 0.536506875544
# Epoch 1916, Minibatch 4/8, Test Error= 0.530356471814
# Epoch 1916, Minibatch 8/8, Test Error= 0.528794599752
# Testing Score= 1.232714842
# Epoch 1917, Minibatch 4/8, Test Error= 0.52856118263
# Epoch 1917, Minibatch 8/8, Test Error= 0.527884063788
# Epoch 1918, Minibatch 4/8, Test Error= 0.529634695045
# Epoch 1918, Minibatch 8/8, Test Error= 0.537186979849
# Testing Score= 1.230314842
# Epoch 1919, Minibatch 4/8, Test Error= 0.529241985294
# Epoch 1919, Minibatch 8/8, Test Error= 0.533434834609
# Epoch 1920, Minibatch 4/8, Test Error= 0.529821372741
# Epoch 1920, Minibatch 8/8, Test Error= 0.530760553108
# Testing Score= 1.231714842
# Epoch 1921, Minibatch 4/8, Test Error= 0.531733632666
# Epoch 1921, Minibatch 8/8, Test Error= 0.52538869732
# Epoch 1922, Minibatch 4/8, Test Error= 0.534463736199
# Epoch 1922, Minibatch 8/8, Test Error= 0.530905070906
# Testing Score= 1.224214842
# Epoch 1923, Minibatch 4/8, Test Error= 0.530172117512
# Epoch 1923, Minibatch 8/8, Test Error= 0.52962503217
# Epoch 1924, Minibatch 4/8, Test Error= 0.534179486875
# Epoch 1924, Minibatch 8/8, Test Error= 0.5302854085
# Testing Score= 1.225314842
# Epoch 1925, Minibatch 4/8, Test Error= 0.535582642537
# Epoch 1925, Minibatch 8/8, Test Error= 0.527833872921
# Epoch 1926, Minibatch 4/8, Test Error= 0.528548809744
# Epoch 1926, Minibatch 8/8, Test Error= 0.526854824919
# Testing Score= 1.231014842
# Epoch 1927, Minibatch 4/8, Test Error= 0.532258722855
# Epoch 1927, Minibatch 8/8, Test Error= 0.529568941229
# Epoch 1928, Minibatch 4/8, Test Error= 0.529671774685
# Epoch 1928, Minibatch 8/8, Test Error= 0.527007158157
# Testing Score= 1.226314842
# Epoch 1929, Minibatch 4/8, Test Error= 0.527880121255
# Epoch 1929, Minibatch 8/8, Test Error= 0.529805369765
# Epoch 1930, Minibatch 4/8, Test Error= 0.528132806857
# Epoch 1930, Minibatch 8/8, Test Error= 0.52977503217
# Testing Score= 1.227414842
# Epoch 1931, Minibatch 4/8, Test Error= 0.527208819795
# Epoch 1931, Minibatch 8/8, Test Error= 0.529739912816
# Epoch 1932, Minibatch 4/8, Test Error= 0.529134352218
# Epoch 1932, Minibatch 8/8, Test Error= 0.530755070906
# Testing Score= 1.225114842
# Epoch 1933, Minibatch 4/8, Test Error= 0.529429296286
# Epoch 1933, Minibatch 8/8, Test Error= 0.52570018192
# Epoch 1934, Minibatch 4/8, Test Error= 0.528776891014
# Epoch 1934, Minibatch 8/8, Test Error= 0.526458100751
# Testing Score= 1.229014842
# Epoch 1935, Minibatch 4/8, Test Error= 0.530833289839
# Epoch 1935, Minibatch 8/8, Test Error= 0.52586964802
# Epoch 1936, Minibatch 4/8, Test Error= 0.529149281963
# Epoch 1936, Minibatch 8/8, Test Error= 0.528623130689
# Testing Score= 1.231714842
# Epoch 1937, Minibatch 4/8, Test Error= 0.531558722855
# Epoch 1937, Minibatch 8/8, Test Error= 0.527590133324
# Epoch 1938, Minibatch 4/8, Test Error= 0.537632642537
# Epoch 1938, Minibatch 8/8, Test Error= 0.527290133324
# Testing Score= 1.226514842
# Epoch 1939, Minibatch 4/8, Test Error= 0.534254829701
# Epoch 1939, Minibatch 8/8, Test Error= 0.525473010088
# Epoch 1940, Minibatch 4/8, Test Error= 0.530052827412
# Epoch 1940, Minibatch 8/8, Test Error= 0.534133226568
# Testing Score= 1.222614842
# Epoch 1941, Minibatch 4/8, Test Error= 0.530324653892
# Epoch 1941, Minibatch 8/8, Test Error= 0.525160166382
# Epoch 1942, Minibatch 4/8, Test Error= 0.526879782912
# Epoch 1942, Minibatch 8/8, Test Error= 0.525191279289
# Testing Score= 1.226414842
# Epoch 1943, Minibatch 4/8, Test Error= 0.524591317576
# Epoch 1943, Minibatch 8/8, Test Error= 0.525920604228
# Epoch 1944, Minibatch 4/8, Test Error= 0.53016752006
# Epoch 1944, Minibatch 8/8, Test Error= 0.528933911432
# Testing Score= 1.227214842
# Epoch 1945, Minibatch 4/8, Test Error= 0.531777643625
# Epoch 1945, Minibatch 8/8, Test Error= 0.526915476151
# Epoch 1946, Minibatch 4/8, Test Error= 0.526852612408
# Epoch 1946, Minibatch 8/8, Test Error= 0.527875245454
# Testing Score= 1.224714842
# Epoch 1947, Minibatch 4/8, Test Error= 0.530943944369
# Epoch 1947, Minibatch 8/8, Test Error= 0.527892256037
# Epoch 1948, Minibatch 4/8, Test Error= 0.531408289839
# Epoch 1948, Minibatch 8/8, Test Error= 0.525197659774
# Testing Score= 1.227714842
# Epoch 1949, Minibatch 4/8, Test Error= 0.528102827412
# Epoch 1949, Minibatch 8/8, Test Error= 0.533278187833
# Epoch 1950, Minibatch 4/8, Test Error= 0.537457642537
# Epoch 1950, Minibatch 8/8, Test Error= 0.529105542268
# Testing Score= 1.228914842
# Epoch 1951, Minibatch 4/8, Test Error= 0.532358722855
# Epoch 1951, Minibatch 8/8, Test Error= 0.53108703245
# Epoch 1952, Minibatch 4/8, Test Error= 0.530007046646
# Epoch 1952, Minibatch 8/8, Test Error= 0.524735166382
# Testing Score= 1.226314842
# Epoch 1953, Minibatch 4/8, Test Error= 0.528007801697
# Epoch 1953, Minibatch 8/8, Test Error= 0.525016622116
# Epoch 1954, Minibatch 4/8, Test Error= 0.52903128117
# Epoch 1954, Minibatch 8/8, Test Error= 0.528846660605
# Testing Score= 1.225214842
# Epoch 1955, Minibatch 4/8, Test Error= 0.527131426142
# Epoch 1955, Minibatch 8/8, Test Error= 0.531630718787
# Epoch 1956, Minibatch 4/8, Test Error= 0.528617051021
# Epoch 1956, Minibatch 8/8, Test Error= 0.528537360838
# Testing Score= 1.228914842
# Epoch 1957, Minibatch 4/8, Test Error= 0.524728676551
# Epoch 1957, Minibatch 8/8, Test Error= 0.531883433064
# Epoch 1958, Minibatch 4/8, Test Error= 0.531238978627
# Epoch 1958, Minibatch 8/8, Test Error= 0.527690133324
# Testing Score= 1.228614842
# Epoch 1959, Minibatch 4/8, Test Error= 0.531433289839
# Epoch 1959, Minibatch 8/8, Test Error= 0.527490476151
# Epoch 1960, Minibatch 4/8, Test Error= 0.527673171091
# Epoch 1960, Minibatch 8/8, Test Error= 0.529011384927
# Testing Score= 1.226414842
# Epoch 1961, Minibatch 4/8, Test Error= 0.532895916116
# Epoch 1961, Minibatch 8/8, Test Error= 0.534609834609
# Epoch 1962, Minibatch 4/8, Test Error= 0.529275059279
# Epoch 1962, Minibatch 8/8, Test Error= 0.535353410465
# Testing Score= 1.223614842
# Epoch 1963, Minibatch 4/8, Test Error= 0.529202185577
# Epoch 1963, Minibatch 8/8, Test Error= 0.528423130689
# Epoch 1964, Minibatch 4/8, Test Error= 0.526469427227
# Epoch 1964, Minibatch 8/8, Test Error= 0.528233631284
# Testing Score= 1.228814842
# Epoch 1965, Minibatch 4/8, Test Error= 0.530788978627
# Epoch 1965, Minibatch 8/8, Test Error= 0.531305070906
# Epoch 1966, Minibatch 4/8, Test Error= 0.529388888437
# Epoch 1966, Minibatch 8/8, Test Error= 0.528690767727
# Testing Score= 1.227314842
# Epoch 1967, Minibatch 4/8, Test Error= 0.530951477046
# Epoch 1967, Minibatch 8/8, Test Error= 0.528413879539
# Epoch 1968, Minibatch 4/8, Test Error= 0.528427484585
# Epoch 1968, Minibatch 8/8, Test Error= 0.527990742114
# Testing Score= 1.232314842
# Epoch 1969, Minibatch 4/8, Test Error= 0.531089060449
# Epoch 1969, Minibatch 8/8, Test Error= 0.534309491782
# Epoch 1970, Minibatch 4/8, Test Error= 0.535129829701
# Epoch 1970, Minibatch 8/8, Test Error= 0.537386979849
# Testing Score= 1.225214842
# Epoch 1971, Minibatch 4/8, Test Error= 0.531346770334
# Epoch 1971, Minibatch 8/8, Test Error= 0.527179130984
# Epoch 1972, Minibatch 4/8, Test Error= 0.527729782912
# Epoch 1972, Minibatch 8/8, Test Error= 0.528376435037
# Testing Score= 1.224514842
# Epoch 1973, Minibatch 4/8, Test Error= 0.529484695045
# Epoch 1973, Minibatch 8/8, Test Error= 0.529218288986
# Epoch 1974, Minibatch 4/8, Test Error= 0.534789079025
# Epoch 1974, Minibatch 8/8, Test Error= 0.526360075176
# Testing Score= 1.223714842
# Epoch 1975, Minibatch 4/8, Test Error= 0.529318944369
# Epoch 1975, Minibatch 8/8, Test Error= 0.525879737582
# Epoch 1976, Minibatch 4/8, Test Error= 0.530532046646
# Epoch 1976, Minibatch 8/8, Test Error= 0.534529497014
# Testing Score= 1.222014842
# Epoch 1977, Minibatch 4/8, Test Error= 0.529806471814
# Epoch 1977, Minibatch 8/8, Test Error= 0.527663245136
# Epoch 1978, Minibatch 4/8, Test Error= 0.529188393472
# Epoch 1978, Minibatch 8/8, Test Error= 0.524628552652
# Testing Score= 1.229614842
# Epoch 1979, Minibatch 4/8, Test Error= 0.525353676551
# Epoch 1979, Minibatch 8/8, Test Error= 0.531656678946
# Epoch 1980, Minibatch 4/8, Test Error= 0.529238840064
# Epoch 1980, Minibatch 8/8, Test Error= 0.525786935955
# Testing Score= 1.229414842
# Epoch 1981, Minibatch 4/8, Test Error= 0.533058722855
# Epoch 1981, Minibatch 8/8, Test Error= 0.536982118733
# Epoch 1982, Minibatch 4/8, Test Error= 0.528406276818
# Epoch 1982, Minibatch 8/8, Test Error= 0.533447514604
# Testing Score= 1.225314842
# Epoch 1983, Minibatch 4/8, Test Error= 0.527389959812
# Epoch 1983, Minibatch 8/8, Test Error= 0.528105730243
# Epoch 1984, Minibatch 4/8, Test Error= 0.530106739317
# Epoch 1984, Minibatch 8/8, Test Error= 0.528810519472
# Testing Score= 1.229914842
# Epoch 1985, Minibatch 4/8, Test Error= 0.528065077652
# Epoch 1985, Minibatch 8/8, Test Error= 0.529023130689
# Epoch 1986, Minibatch 4/8, Test Error= 0.527362147118
# Epoch 1986, Minibatch 8/8, Test Error= 0.526849548279
# Testing Score= 1.225614842
# Epoch 1987, Minibatch 4/8, Test Error= 0.528917051021
# Epoch 1987, Minibatch 8/8, Test Error= 0.530531600595
# Epoch 1988, Minibatch 4/8, Test Error= 0.531233289839
# Epoch 1988, Minibatch 8/8, Test Error= 0.525045604228
# Testing Score= 1.234614842
# Epoch 1989, Minibatch 4/8, Test Error= 0.52920089625
# Epoch 1989, Minibatch 8/8, Test Error= 0.528319144225
# Epoch 1990, Minibatch 4/8, Test Error= 0.525519082491
# Epoch 1990, Minibatch 8/8, Test Error= 0.525670604228
# Testing Score= 1.229714842
# Epoch 1991, Minibatch 4/8, Test Error= 0.534234065682
# Epoch 1991, Minibatch 8/8, Test Error= 0.529610430132
# Epoch 1992, Minibatch 4/8, Test Error= 0.531368944369
# Epoch 1992, Minibatch 8/8, Test Error= 0.529268288986
# Testing Score= 1.225414842
# Epoch 1993, Minibatch 4/8, Test Error= 0.537282642537
# Epoch 1993, Minibatch 8/8, Test Error= 0.529950024038
# Epoch 1994, Minibatch 4/8, Test Error= 0.529254639113
# Epoch 1994, Minibatch 8/8, Test Error= 0.529165767727
# Testing Score= 1.224514842
# Epoch 1995, Minibatch 4/8, Test Error= 0.528248058819
# Epoch 1995, Minibatch 8/8, Test Error= 0.525222051006
# Epoch 1996, Minibatch 4/8, Test Error= 0.532283722855
# Epoch 1996, Minibatch 8/8, Test Error= 0.534404497014
# Testing Score= 1.222114842
# Epoch 1997, Minibatch 4/8, Test Error= 0.53165690483
# Epoch 1997, Minibatch 8/8, Test Error= 0.526557158157
# Epoch 1998, Minibatch 4/8, Test Error= 0.531366670041
# Epoch 1998, Minibatch 8/8, Test Error= 0.537769391427
# Testing Score= 1.226714842
# Epoch 1999, Minibatch 4/8, Test Error= 0.53002396946
# Epoch 1999, Minibatch 8/8, Test Error= 0.53873828903
# Epoch 2000, Minibatch 4/8, Test Error= 0.528558986643
# Epoch 2000, Minibatch 8/8, Test Error= 0.526607158157
# Testing Score= 1.222914842

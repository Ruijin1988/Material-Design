# %%
import scipy.io
import numpy as np
import theano
import theano.tensor as T
from theano.tensor.signal import pool
import random

#import input data
neurons = scipy.io.loadmat('input_neuron')
neuron_input = neurons['WB']
neuron_train = neuron_input[0:80]
neuron_test = neuron_input[80:100]

force = scipy.io.loadmat('true.mat')
data_label=np.asarray(force['skt']).reshape(-1)
label_y=(data_label-np.mean(data_label))/np.std(data_label)
label_train=label_y[0:80]
label_test=label_y[80:100]

# %%
label_test.shape
# Out:
# (20L,)

# %%
def load_data(data1, data2):
    def shared_dataset(data1,data2,borrow=True):
        shared_x = theano.shared(np.asarray(data1, dtype=theano.config.floatX),borrow=True)
        shared_y = theano.shared(np.asarray(data2, dtype=theano.config.floatX),borrow=True)
        return shared_x, T.cast(shared_y,'float64')
    
    train_set_x, train_set_y = shared_dataset(data1,data2)
    rval = [(train_set_x, train_set_y)]
    return rval

class RBM_NN(object):
    def __init__(self, input, n_in, n_out):
        self.W = theano.shared(value=np.zeros((n_in, n_out),dtype=theano.config.floatX),name='W',borrow=True)
        self.b = theano.shared(value=np.zeros((n_out,),dtype=theano.config.floatX),name='b',borrow=True)               
        self.y_pred = T.dot(input, self.W)+self.b      
        self.params = [self.W, self.b]
        
    def difference(self,y):
        return T.mean(abs(self.y_pred-T.reshape(y,[10,1])))
    
class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out):
        self.input = input
        W_values = np.asarray(rng.uniform(low=-np.sqrt(6./(n_in+n_out)),
                                          high=np.sqrt(6./(n_in+n_out)),
                                          size=(n_in,n_out)),
                              dtype=theano.config.floatX)
        W = theano.shared(value=W_values, name='W',borrow=True)
        
        b_values = np.zeros((n_out,),dtype=theano.config.floatX)
        b = theano.shared(value=b_values, name='b',borrow=True)
        
        self.W=W
        self.b=b
        
        lin_output = T.dot(input,self.W) + self.b
        self.output = T.nnet.sigmoid(lin_output)
        
        self.params = [self.W, self.b]

class MLP(object):
    def __init__(self, rng,input,n_in, n_hidden, n_out):
        self.hiddenLayer1 = HiddenLayer(rng,
                                       input=input,
                                       n_in=n_in,
                                       n_out=n_hidden)
        
        self.LR=RBM_NN(input=self.hiddenLayer1.output,
                      n_in=n_hidden,
                      n_out=n_out)
        
        self.L2_sqr = ((self.hiddenLayer1.W**2).sum()+
                       (self.LR.W**2).sum()
                      )
        
        
        self.error = (self.LR.difference)
        
        self.params = self.hiddenLayer1.params + self.LR.params
        
        self.input = input

        
def test_mlp(learning_rate=0.01, n_epochs=1000,  data1=neuron_train, data2=label_train,
             data3=neuron_test, data4=label_test, batch_size=10, n_hidden=1000):
    datasets_train = load_data(data1,data2)
    datasets_test = load_data(data3,data4)
    
    train_set_x, train_set_y = datasets_train[0]
    test_set_x, test_set_y = datasets_test[0]
    
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] // batch_size
    n_test_batches = test_set_x.get_value(borrow=True).shape[0]//batch_size
    
    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')
    index = T.lscalar()
    x = T.matrix('x')
    y = T.vector('y')    
    
    rng = np.random.RandomState(1234)
    
    classifier = MLP(rng=rng,
                    input=x,
                    n_in=200*200,
                    n_hidden=n_hidden,
                    n_out=1)
    
    cost=(classifier.error(y)+0.0001*classifier.L2_sqr)
    
    test_model = theano.function(inputs=[index],
                                outputs=classifier.error(y),
                                givens={
            x:test_set_x[index*batch_size:(index+1)*batch_size],
            y:test_set_y[index*batch_size:(index+1)*batch_size]
        })
    
    gparams = [T.grad(cost,param) for param in classifier.params]
    
    updates = [(param, param - learning_rate*gparam) for 
              param, gparam in zip(classifier.params, gparams)]
    
    train_model = theano.function(inputs=[index],
                                 outputs=cost,
                                 updates=updates,
                                 givens={
            x: train_set_x[index*batch_size:(index+1)*batch_size],
            y: train_set_y[index*batch_size:(index+1)*batch_size]
        })

    ###############
    # TRAIN MODEL #
    ###############
    print('... training the model')
    
    epoch=0 
    while (epoch<n_epochs):
        epoch = epoch + 1
        #print epoch
        #if epoch != 1:
        #    W=test_mlp2()
            
        for minibatch_index in range(n_train_batches): 
            minibatch_avg_cost=train_model(minibatch_index)    
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index
            #print iter
            if (iter + 1) % 8 == 0:
                # compute zero-one loss on validation set
                losses = [train_model(i) for i in range(n_train_batches)]
                this_loss = np.mean(losses)
                
                print "Epoch {0}, Minibatch {1}/{2}, Test Error= {3}".format(epoch,minibatch_index+1,n_train_batches,
                                                                       this_loss)

        if epoch%10==0:
            test_losses = [test_model(i) for i in range(n_test_batches)]
            print test_losses
            test_score = np.mean(test_losses)
            
            print "Testing Score= {0}".format(test_score)
            
            
    return classifier.params

# %%
W=test_mlp()
# Out:
# ... building the model
# ... training the model
# Epoch 1, Minibatch 8/8, Test Error= 0.943471973512
# Epoch 2, Minibatch 8/8, Test Error= 0.968223521329
# Epoch 3, Minibatch 8/8, Test Error= 0.907507312838
# Epoch 4, Minibatch 8/8, Test Error= 0.930128434004
# Epoch 5, Minibatch 8/8, Test Error= 0.87718740184
# Epoch 6, Minibatch 8/8, Test Error= 0.847316133485
# Epoch 7, Minibatch 8/8, Test Error= 0.82345338587
# Epoch 8, Minibatch 8/8, Test Error= 0.932339532924
# Epoch 9, Minibatch 8/8, Test Error= 0.830162665901
# Epoch 10, Minibatch 8/8, Test Error= 0.838289103166
# [array(0.8436274721366901), array(1.1590887305512894)]
# Testing Score= 1.00135810134
# Epoch 11, Minibatch 8/8, Test Error= 0.756657173267
# Epoch 12, Minibatch 8/8, Test Error= 0.792891459145
# Epoch 13, Minibatch 8/8, Test Error= 0.707948360249
# Epoch 14, Minibatch 8/8, Test Error= 0.659981064603
# Epoch 15, Minibatch 8/8, Test Error= 0.688541540521
# Epoch 16, Minibatch 8/8, Test Error= 0.66237269433
# Epoch 17, Minibatch 8/8, Test Error= 0.714250496438
# Epoch 18, Minibatch 8/8, Test Error= 0.687840942477
# Epoch 19, Minibatch 8/8, Test Error= 0.65413802004
# Epoch 20, Minibatch 8/8, Test Error= 0.708377032521
# [array(0.8650103923287439), array(0.9983634694702517)]
# Testing Score= 0.931686930899
# Epoch 21, Minibatch 8/8, Test Error= 0.708875197705
# Epoch 22, Minibatch 8/8, Test Error= 0.589066351085
# Epoch 23, Minibatch 8/8, Test Error= 0.586346265838
# Epoch 24, Minibatch 8/8, Test Error= 0.598083468479
# Epoch 25, Minibatch 8/8, Test Error= 0.574918396361
# Epoch 26, Minibatch 8/8, Test Error= 0.586879440377
# Epoch 27, Minibatch 8/8, Test Error= 0.546201894345
# Epoch 28, Minibatch 8/8, Test Error= 0.539739831323
# Epoch 29, Minibatch 8/8, Test Error= 0.537797031778
# Epoch 30, Minibatch 8/8, Test Error= 0.611284514807
# [array(0.8687765135756089), array(0.9844308521441439)]
# Testing Score= 0.92660368286
# Epoch 31, Minibatch 8/8, Test Error= 0.537559854162
# Epoch 32, Minibatch 8/8, Test Error= 0.499360949224
# Epoch 33, Minibatch 8/8, Test Error= 0.525512965818
# Epoch 34, Minibatch 8/8, Test Error= 0.510518926878
# Epoch 35, Minibatch 8/8, Test Error= 0.578243528224
# Epoch 36, Minibatch 8/8, Test Error= 0.512257144341
# Epoch 37, Minibatch 8/8, Test Error= 0.488794351183
# Epoch 38, Minibatch 8/8, Test Error= 0.462828481178
# Epoch 39, Minibatch 8/8, Test Error= 0.428564576676
# Epoch 40, Minibatch 8/8, Test Error= 0.400888979381
# [array(0.9628950069411782), array(0.9329305261324221)]
# Testing Score= 0.947912766537
# Epoch 41, Minibatch 8/8, Test Error= 0.417985675139
# Epoch 42, Minibatch 8/8, Test Error= 0.459438711343
# Epoch 43, Minibatch 8/8, Test Error= 0.411825338892
# Epoch 44, Minibatch 8/8, Test Error= 0.426635718626
# Epoch 45, Minibatch 8/8, Test Error= 0.444766746828
# Epoch 46, Minibatch 8/8, Test Error= 0.401149167134
# Epoch 47, Minibatch 8/8, Test Error= 0.422461913925
# Epoch 48, Minibatch 8/8, Test Error= 0.437520114067
# Epoch 49, Minibatch 8/8, Test Error= 0.345264231889
# Epoch 50, Minibatch 8/8, Test Error= 0.432803997838
# [array(0.9002416655509933), array(0.9663556446848556)]
# Testing Score= 0.933298655118
# Epoch 51, Minibatch 8/8, Test Error= 0.388398094023
# Epoch 52, Minibatch 8/8, Test Error= 0.392454646029
# Epoch 53, Minibatch 8/8, Test Error= 0.341082972429
# Epoch 54, Minibatch 8/8, Test Error= 0.353394904712
# Epoch 55, Minibatch 8/8, Test Error= 0.35066693068
# Epoch 56, Minibatch 8/8, Test Error= 0.327056581679
# Epoch 57, Minibatch 8/8, Test Error= 0.37667139705
# Epoch 58, Minibatch 8/8, Test Error= 0.335420525431
# Epoch 59, Minibatch 8/8, Test Error= 0.336291667706
# Epoch 60, Minibatch 8/8, Test Error= 0.347389870023
# [array(0.9386238180531272), array(0.9584628243607713)]
# Testing Score= 0.948543321207
# Epoch 61, Minibatch 8/8, Test Error= 0.317574931709
# Epoch 62, Minibatch 8/8, Test Error= 0.35925729143
# Epoch 63, Minibatch 8/8, Test Error= 0.331686610275
# Epoch 64, Minibatch 8/8, Test Error= 0.36947906979
# Epoch 65, Minibatch 8/8, Test Error= 0.333040403795
# Epoch 66, Minibatch 8/8, Test Error= 0.367318460236
# Epoch 67, Minibatch 8/8, Test Error= 0.311656775205
# Epoch 68, Minibatch 8/8, Test Error= 0.340355041806
# Epoch 69, Minibatch 8/8, Test Error= 0.315127407284
# Epoch 70, Minibatch 8/8, Test Error= 0.349983604214
# [array(0.9356703725884425), array(0.9680575844589854)]
# Testing Score= 0.951863978524
# Epoch 71, Minibatch 8/8, Test Error= 0.335891401159
# Epoch 72, Minibatch 8/8, Test Error= 0.285745553452
# Epoch 73, Minibatch 8/8, Test Error= 0.312195909467
# Epoch 74, Minibatch 8/8, Test Error= 0.311604501831
# Epoch 75, Minibatch 8/8, Test Error= 0.302269239542
# Epoch 76, Minibatch 8/8, Test Error= 0.320619859235
# Epoch 77, Minibatch 8/8, Test Error= 0.312873509408
# Epoch 78, Minibatch 8/8, Test Error= 0.308911218561
# Epoch 79, Minibatch 8/8, Test Error= 0.31350439173
# Epoch 80, Minibatch 8/8, Test Error= 0.296119337167
# [array(0.9379324418110311), array(0.9461115506728159)]
# Testing Score= 0.942021996242
# Epoch 81, Minibatch 8/8, Test Error= 0.308641086545
# Epoch 82, Minibatch 8/8, Test Error= 0.295642822078
# Epoch 83, Minibatch 8/8, Test Error= 0.309598145817
# Epoch 84, Minibatch 8/8, Test Error= 0.300377483052
# Epoch 85, Minibatch 8/8, Test Error= 0.284086356876
# Epoch 86, Minibatch 8/8, Test Error= 0.309757368177
# Epoch 87, Minibatch 8/8, Test Error= 0.292424392138
# Epoch 88, Minibatch 8/8, Test Error= 0.297578695147
# Epoch 89, Minibatch 8/8, Test Error= 0.289804858875
# Epoch 90, Minibatch 8/8, Test Error= 0.293806190466
# [array(0.9033244361148848), array(0.9874112464251346)]
# Testing Score= 0.94536784127
# Epoch 91, Minibatch 8/8, Test Error= 0.298096894952
# Epoch 92, Minibatch 8/8, Test Error= 0.29751169507
# Epoch 93, Minibatch 8/8, Test Error= 0.279622916385
# Epoch 94, Minibatch 8/8, Test Error= 0.275272937376
# Epoch 95, Minibatch 8/8, Test Error= 0.27756999351
# Epoch 96, Minibatch 8/8, Test Error= 0.26901438222
# Epoch 97, Minibatch 8/8, Test Error= 0.26419347902
# Epoch 98, Minibatch 8/8, Test Error= 0.280667074947
# Epoch 99, Minibatch 8/8, Test Error= 0.259423379562
# Epoch 100, Minibatch 8/8, Test Error= 0.262966343696
# [array(0.9133118401119023), array(0.9922190903766717)]
# Testing Score= 0.952765465244
# Epoch 101, Minibatch 8/8, Test Error= 0.259699695859
# Epoch 102, Minibatch 8/8, Test Error= 0.262536057955
# Epoch 103, Minibatch 8/8, Test Error= 0.279206392819
# Epoch 104, Minibatch 8/8, Test Error= 0.257040965227
# Epoch 105, Minibatch 8/8, Test Error= 0.262285282893
# Epoch 106, Minibatch 8/8, Test Error= 0.25754373727
# Epoch 107, Minibatch 8/8, Test Error= 0.253524434793
# Epoch 108, Minibatch 8/8, Test Error= 0.256128557523
# Epoch 109, Minibatch 8/8, Test Error= 0.255179727465
# Epoch 110, Minibatch 8/8, Test Error= 0.239394305422
# [array(0.9007190376665932), array(0.9740140688655796)]
# Testing Score= 0.937366553266
# Epoch 111, Minibatch 8/8, Test Error= 0.250730343732
# Epoch 112, Minibatch 8/8, Test Error= 0.269051537602
# Epoch 113, Minibatch 8/8, Test Error= 0.272361819073
# Epoch 114, Minibatch 8/8, Test Error= 0.249836448333
# Epoch 115, Minibatch 8/8, Test Error= 0.264701982645
# Epoch 116, Minibatch 8/8, Test Error= 0.263389782392
# Epoch 117, Minibatch 8/8, Test Error= 0.245832819754
# Epoch 118, Minibatch 8/8, Test Error= 0.255423751482
# Epoch 119, Minibatch 8/8, Test Error= 0.255629878654
# Epoch 120, Minibatch 8/8, Test Error= 0.26301931772
# [array(0.8908355024971435), array(0.973607132822881)]
# Testing Score= 0.93222131766
# Epoch 121, Minibatch 8/8, Test Error= 0.245777790357
# Epoch 122, Minibatch 8/8, Test Error= 0.25189527738
# Epoch 123, Minibatch 8/8, Test Error= 0.242495847662
# Epoch 124, Minibatch 8/8, Test Error= 0.258485267153
# Epoch 125, Minibatch 8/8, Test Error= 0.244514803785
# Epoch 126, Minibatch 8/8, Test Error= 0.260220140536
# Epoch 127, Minibatch 8/8, Test Error= 0.242304652555
# Epoch 128, Minibatch 8/8, Test Error= 0.247452808432
# Epoch 129, Minibatch 8/8, Test Error= 0.236476927086
# Epoch 130, Minibatch 8/8, Test Error= 0.24876140451
# [array(0.9119207546857886), array(0.9884838800976519)]
# Testing Score= 0.950202317392
# Epoch 131, Minibatch 8/8, Test Error= 0.249923277277
# Epoch 132, Minibatch 8/8, Test Error= 0.239035541081
# Epoch 133, Minibatch 8/8, Test Error= 0.257129099656
# Epoch 134, Minibatch 8/8, Test Error= 0.256383015391
# Epoch 135, Minibatch 8/8, Test Error= 0.247995446107
# Epoch 136, Minibatch 8/8, Test Error= 0.253710577142
# Epoch 137, Minibatch 8/8, Test Error= 0.263253191471
# Epoch 138, Minibatch 8/8, Test Error= 0.238935266371
# Epoch 139, Minibatch 8/8, Test Error= 0.255760177593
# Epoch 140, Minibatch 8/8, Test Error= 0.263104281434
# [array(0.9225278000219529), array(0.9580784537892935)]
# Testing Score= 0.940303126906
# Epoch 141, Minibatch 8/8, Test Error= 0.237240179664
# Epoch 142, Minibatch 8/8, Test Error= 0.246370821348
# Epoch 143, Minibatch 8/8, Test Error= 0.252522503037
# Epoch 144, Minibatch 8/8, Test Error= 0.227180056514
# Epoch 145, Minibatch 8/8, Test Error= 0.254882423637
# Epoch 146, Minibatch 8/8, Test Error= 0.236930703559
# Epoch 147, Minibatch 8/8, Test Error= 0.242274646458
# Epoch 148, Minibatch 8/8, Test Error= 0.234730368968
# Epoch 149, Minibatch 8/8, Test Error= 0.249134835952
# Epoch 150, Minibatch 8/8, Test Error= 0.243348023247
# [array(0.879743463327693), array(1.015537317936896)]
# Testing Score= 0.947640390632
# Epoch 151, Minibatch 8/8, Test Error= 0.242144044479
# Epoch 152, Minibatch 8/8, Test Error= 0.233584136488
# Epoch 153, Minibatch 8/8, Test Error= 0.23651185217
# Epoch 154, Minibatch 8/8, Test Error= 0.23988684777
# Epoch 155, Minibatch 8/8, Test Error= 0.239037321944
# Epoch 156, Minibatch 8/8, Test Error= 0.243688368233
# Epoch 157, Minibatch 8/8, Test Error= 0.242397406701
# Epoch 158, Minibatch 8/8, Test Error= 0.264316389496
# Epoch 159, Minibatch 8/8, Test Error= 0.219831001836
# Epoch 160, Minibatch 8/8, Test Error= 0.237860658111
# [array(0.9091665579741909), array(0.9939527285108888)]
# Testing Score= 0.951559643243
# Epoch 161, Minibatch 8/8, Test Error= 0.229708984574
# Epoch 162, Minibatch 8/8, Test Error= 0.240246076943
# Epoch 163, Minibatch 8/8, Test Error= 0.236722349363
# Epoch 164, Minibatch 8/8, Test Error= 0.237842078934
# Epoch 165, Minibatch 8/8, Test Error= 0.230681854294
# Epoch 166, Minibatch 8/8, Test Error= 0.236613308655
# Epoch 167, Minibatch 8/8, Test Error= 0.22326261696
# Epoch 168, Minibatch 8/8, Test Error= 0.235341915143
# Epoch 169, Minibatch 8/8, Test Error= 0.241204112494
# Epoch 170, Minibatch 8/8, Test Error= 0.241072677546
# [array(0.8820901737664499), array(1.0287626343838419)]
# Testing Score= 0.955426404075
# Epoch 171, Minibatch 8/8, Test Error= 0.24083891211
# Epoch 172, Minibatch 8/8, Test Error= 0.232208257622
# Epoch 173, Minibatch 8/8, Test Error= 0.222892192617
# Epoch 174, Minibatch 8/8, Test Error= 0.229699185438
# Epoch 175, Minibatch 8/8, Test Error= 0.231780749597
# Epoch 176, Minibatch 8/8, Test Error= 0.237616218002
# Epoch 177, Minibatch 8/8, Test Error= 0.232121828418
# Epoch 178, Minibatch 8/8, Test Error= 0.243796579855
# Epoch 179, Minibatch 8/8, Test Error= 0.237384707768
# Epoch 180, Minibatch 8/8, Test Error= 0.243420079695
# [array(0.8964017118738201), array(1.008110095021173)]
# Testing Score= 0.952255903447
# Epoch 181, Minibatch 8/8, Test Error= 0.225344251262
# Epoch 182, Minibatch 8/8, Test Error= 0.229867674793
# Epoch 183, Minibatch 8/8, Test Error= 0.226485991511
# Epoch 184, Minibatch 8/8, Test Error= 0.234459972547
# Epoch 185, Minibatch 8/8, Test Error= 0.237371578241
# Epoch 186, Minibatch 8/8, Test Error= 0.233347997896
# Epoch 187, Minibatch 8/8, Test Error= 0.222249693741
# Epoch 188, Minibatch 8/8, Test Error= 0.225104367721
# Epoch 189, Minibatch 8/8, Test Error= 0.222581784919
# Epoch 190, Minibatch 8/8, Test Error= 0.227912036485
# [array(0.9191763778766158), array(0.9585553323483641)]
# Testing Score= 0.938865855112
# Epoch 191, Minibatch 8/8, Test Error= 0.222371472837
# Epoch 192, Minibatch 8/8, Test Error= 0.224429358743
# Epoch 193, Minibatch 8/8, Test Error= 0.22771308429
# Epoch 194, Minibatch 8/8, Test Error= 0.217312758127
# Epoch 195, Minibatch 8/8, Test Error= 0.226233016917
# Epoch 196, Minibatch 8/8, Test Error= 0.225332244403
# Epoch 197, Minibatch 8/8, Test Error= 0.22497744124
# Epoch 198, Minibatch 8/8, Test Error= 0.23230813688
# Epoch 199, Minibatch 8/8, Test Error= 0.224099721907
# Epoch 200, Minibatch 8/8, Test Error= 0.232417360108
# [array(0.9154685216434167), array(0.9887151293564379)]
# Testing Score= 0.9520918255
# Epoch 201, Minibatch 8/8, Test Error= 0.225889509244
# Epoch 202, Minibatch 8/8, Test Error= 0.230354961336
# Epoch 203, Minibatch 8/8, Test Error= 0.228228874636
# Epoch 204, Minibatch 8/8, Test Error= 0.219061641998
# Epoch 205, Minibatch 8/8, Test Error= 0.229439948419
# Epoch 206, Minibatch 8/8, Test Error= 0.225375984867
# Epoch 207, Minibatch 8/8, Test Error= 0.233414513392
# Epoch 208, Minibatch 8/8, Test Error= 0.229010288417
# Epoch 209, Minibatch 8/8, Test Error= 0.222073928706
# Epoch 210, Minibatch 8/8, Test Error= 0.227838216382
# [array(0.8900625547466163), array(1.0085953896319577)]
# Testing Score= 0.949328972189
# Epoch 211, Minibatch 8/8, Test Error= 0.219590323084
# Epoch 212, Minibatch 8/8, Test Error= 0.219958914617
# Epoch 213, Minibatch 8/8, Test Error= 0.221459076091
# Epoch 214, Minibatch 8/8, Test Error= 0.234538128307
# Epoch 215, Minibatch 8/8, Test Error= 0.229815612715
# Epoch 216, Minibatch 8/8, Test Error= 0.218932470654
# Epoch 217, Minibatch 8/8, Test Error= 0.226554024904
# Epoch 218, Minibatch 8/8, Test Error= 0.22960578097
# Epoch 219, Minibatch 8/8, Test Error= 0.223353932276
# Epoch 220, Minibatch 8/8, Test Error= 0.220395481975
# [array(0.894265229188792), array(0.9952862816417409)]
# Testing Score= 0.944775755415
# Epoch 221, Minibatch 8/8, Test Error= 0.223332709178
# Epoch 222, Minibatch 8/8, Test Error= 0.217859293734
# Epoch 223, Minibatch 8/8, Test Error= 0.218719161688
# Epoch 224, Minibatch 8/8, Test Error= 0.227459278619
# Epoch 225, Minibatch 8/8, Test Error= 0.21506907197
# Epoch 226, Minibatch 8/8, Test Error= 0.217739978718
# Epoch 227, Minibatch 8/8, Test Error= 0.223879597553
# Epoch 228, Minibatch 8/8, Test Error= 0.212656439042
# Epoch 229, Minibatch 8/8, Test Error= 0.219490205957
# Epoch 230, Minibatch 8/8, Test Error= 0.218456430539
# [array(0.9115056914086797), array(0.9789333641308756)]
# Testing Score= 0.94521952777
# Epoch 231, Minibatch 8/8, Test Error= 0.232064861751
# Epoch 232, Minibatch 8/8, Test Error= 0.228373913693
# Epoch 233, Minibatch 8/8, Test Error= 0.21553774889
# Epoch 234, Minibatch 8/8, Test Error= 0.220871538034
# Epoch 235, Minibatch 8/8, Test Error= 0.222342963191
# Epoch 236, Minibatch 8/8, Test Error= 0.223608172422
# Epoch 237, Minibatch 8/8, Test Error= 0.21907702378
# Epoch 238, Minibatch 8/8, Test Error= 0.216747435357
# Epoch 239, Minibatch 8/8, Test Error= 0.218364640196
# Epoch 240, Minibatch 8/8, Test Error= 0.2167807396
# [array(0.9208227328250841), array(0.9690068752268892)]
# Testing Score= 0.944914804026
# Epoch 241, Minibatch 8/8, Test Error= 0.214251009787
# Epoch 242, Minibatch 8/8, Test Error= 0.212348105457
# Epoch 243, Minibatch 8/8, Test Error= 0.22099350525
# Epoch 244, Minibatch 8/8, Test Error= 0.227088671323
# Epoch 245, Minibatch 8/8, Test Error= 0.218320474189
# Epoch 246, Minibatch 8/8, Test Error= 0.216172829472
# Epoch 247, Minibatch 8/8, Test Error= 0.215311770429
# Epoch 248, Minibatch 8/8, Test Error= 0.217154468489
# Epoch 249, Minibatch 8/8, Test Error= 0.223318336552
# Epoch 250, Minibatch 8/8, Test Error= 0.21740637458
# [array(0.9141884323067819), array(0.9662167200473142)]
# Testing Score= 0.940202576177
# Epoch 251, Minibatch 8/8, Test Error= 0.221300994622
# Epoch 252, Minibatch 8/8, Test Error= 0.219832530443
# Epoch 253, Minibatch 8/8, Test Error= 0.219096150735
# Epoch 254, Minibatch 8/8, Test Error= 0.221776272251
# Epoch 255, Minibatch 8/8, Test Error= 0.21645313824
# Epoch 256, Minibatch 8/8, Test Error= 0.219601146211
# Epoch 257, Minibatch 8/8, Test Error= 0.220669341194
# Epoch 258, Minibatch 8/8, Test Error= 0.220594412333
# Epoch 259, Minibatch 8/8, Test Error= 0.219259247893
# Epoch 260, Minibatch 8/8, Test Error= 0.221911065488
# [array(0.9162603764145718), array(0.9682243183301906)]
# Testing Score= 0.942242347372
# Epoch 261, Minibatch 8/8, Test Error= 0.218603527224
# Epoch 262, Minibatch 8/8, Test Error= 0.211664989586
# Epoch 263, Minibatch 8/8, Test Error= 0.21884432421
# Epoch 264, Minibatch 8/8, Test Error= 0.215187766732
# Epoch 265, Minibatch 8/8, Test Error= 0.221547164749
# Epoch 266, Minibatch 8/8, Test Error= 0.215794498613
# Epoch 267, Minibatch 8/8, Test Error= 0.215259673103
# Epoch 268, Minibatch 8/8, Test Error= 0.219907361802
# Epoch 269, Minibatch 8/8, Test Error= 0.216142554907
# Epoch 270, Minibatch 8/8, Test Error= 0.21771047418
# [array(0.9064556099757676), array(0.9752598394221069)]
# Testing Score= 0.940857724699
# Epoch 271, Minibatch 8/8, Test Error= 0.212990509939
# Epoch 272, Minibatch 8/8, Test Error= 0.213045592715
# Epoch 273, Minibatch 8/8, Test Error= 0.212289677373
# Epoch 274, Minibatch 8/8, Test Error= 0.215798503946
# Epoch 275, Minibatch 8/8, Test Error= 0.223850779493
# Epoch 276, Minibatch 8/8, Test Error= 0.211999645247
# Epoch 277, Minibatch 8/8, Test Error= 0.21177740227
# Epoch 278, Minibatch 8/8, Test Error= 0.218716971888
# Epoch 279, Minibatch 8/8, Test Error= 0.214136119268
# Epoch 280, Minibatch 8/8, Test Error= 0.222011414747
# [array(0.9050788807846908), array(0.9687502312410554)]
# Testing Score= 0.936914556013
# Epoch 281, Minibatch 8/8, Test Error= 0.220058680828
# Epoch 282, Minibatch 8/8, Test Error= 0.217485573346
# Epoch 283, Minibatch 8/8, Test Error= 0.217573434105
# Epoch 284, Minibatch 8/8, Test Error= 0.215768160924
# Epoch 285, Minibatch 8/8, Test Error= 0.215630295967
# Epoch 286, Minibatch 8/8, Test Error= 0.218507818089
# Epoch 287, Minibatch 8/8, Test Error= 0.220276180235
# Epoch 288, Minibatch 8/8, Test Error= 0.208748095714
# Epoch 289, Minibatch 8/8, Test Error= 0.215295283533
# Epoch 290, Minibatch 8/8, Test Error= 0.219761576569
# [array(0.9043310427031674), array(0.9600324975700099)]
# Testing Score= 0.932181770137
# Epoch 291, Minibatch 8/8, Test Error= 0.216089257769
# Epoch 292, Minibatch 8/8, Test Error= 0.212115630254
# Epoch 293, Minibatch 8/8, Test Error= 0.223981848632
# Epoch 294, Minibatch 8/8, Test Error= 0.219730132321
# Epoch 295, Minibatch 8/8, Test Error= 0.218189387659
# Epoch 296, Minibatch 8/8, Test Error= 0.215389638402
# Epoch 297, Minibatch 8/8, Test Error= 0.21043972654
# Epoch 298, Minibatch 8/8, Test Error= 0.213578609545
# Epoch 299, Minibatch 8/8, Test Error= 0.225107416992
# Epoch 300, Minibatch 8/8, Test Error= 0.215301441945
# [array(0.9035624242315723), array(0.9791626422362217)]
# Testing Score= 0.941362533234
# Epoch 301, Minibatch 8/8, Test Error= 0.210215717164
# Epoch 302, Minibatch 8/8, Test Error= 0.21657795398
# Epoch 303, Minibatch 8/8, Test Error= 0.215489055151
# Epoch 304, Minibatch 8/8, Test Error= 0.217018270099
# Epoch 305, Minibatch 8/8, Test Error= 0.214121446202
# Epoch 306, Minibatch 8/8, Test Error= 0.215904744985
# Epoch 307, Minibatch 8/8, Test Error= 0.212785072007
# Epoch 308, Minibatch 8/8, Test Error= 0.215428534716
# Epoch 309, Minibatch 8/8, Test Error= 0.216043790665
# Epoch 310, Minibatch 8/8, Test Error= 0.215384891949
# [array(0.9012955932560158), array(0.9772199814430307)]
# Testing Score= 0.93925778735
# Epoch 311, Minibatch 8/8, Test Error= 0.21505769381
# Epoch 312, Minibatch 8/8, Test Error= 0.213219971631
# Epoch 313, Minibatch 8/8, Test Error= 0.217652857106
# Epoch 314, Minibatch 8/8, Test Error= 0.220895348319
# Epoch 315, Minibatch 8/8, Test Error= 0.217223708182
# Epoch 316, Minibatch 8/8, Test Error= 0.215426796954
# Epoch 317, Minibatch 8/8, Test Error= 0.210772446791
# Epoch 318, Minibatch 8/8, Test Error= 0.217586476752
# Epoch 319, Minibatch 8/8, Test Error= 0.220877314761
# Epoch 320, Minibatch 8/8, Test Error= 0.217520670257
# [array(0.9007808280384995), array(0.9689123998627203)]
# Testing Score= 0.934846613951
# Epoch 321, Minibatch 8/8, Test Error= 0.215261167422
# Epoch 322, Minibatch 8/8, Test Error= 0.21607890771
# Epoch 323, Minibatch 8/8, Test Error= 0.210298523582
# Epoch 324, Minibatch 8/8, Test Error= 0.216848175168
# Epoch 325, Minibatch 8/8, Test Error= 0.215516687628
# Epoch 326, Minibatch 8/8, Test Error= 0.212445058677
# Epoch 327, Minibatch 8/8, Test Error= 0.218255745966
# Epoch 328, Minibatch 8/8, Test Error= 0.216227903068
# Epoch 329, Minibatch 8/8, Test Error= 0.21473442746
# Epoch 330, Minibatch 8/8, Test Error= 0.217682617694
# [array(0.9138454929359888), array(0.9645036672752634)]
# Testing Score= 0.939174580106
# Epoch 331, Minibatch 8/8, Test Error= 0.207683238207
# Epoch 332, Minibatch 8/8, Test Error= 0.218168408324
# Epoch 333, Minibatch 8/8, Test Error= 0.214138469703
# Epoch 334, Minibatch 8/8, Test Error= 0.214515376207
# Epoch 335, Minibatch 8/8, Test Error= 0.210567397252
# Epoch 336, Minibatch 8/8, Test Error= 0.217220216296
# Epoch 337, Minibatch 8/8, Test Error= 0.210658820496
# Epoch 338, Minibatch 8/8, Test Error= 0.215717473552
# Epoch 339, Minibatch 8/8, Test Error= 0.208456649498
# Epoch 340, Minibatch 8/8, Test Error= 0.212625697881
# [array(0.9072912272925185), array(0.9649015887240932)]
# Testing Score= 0.936096408008
# Epoch 341, Minibatch 8/8, Test Error= 0.213961961995
# Epoch 342, Minibatch 8/8, Test Error= 0.204699854057
# Epoch 343, Minibatch 8/8, Test Error= 0.218580748192
# Epoch 344, Minibatch 8/8, Test Error= 0.208431349601
# Epoch 345, Minibatch 8/8, Test Error= 0.214965988322
# Epoch 346, Minibatch 8/8, Test Error= 0.215646537806
# Epoch 347, Minibatch 8/8, Test Error= 0.211230872315
# Epoch 348, Minibatch 8/8, Test Error= 0.212197157447
# Epoch 349, Minibatch 8/8, Test Error= 0.213260776574
# Epoch 350, Minibatch 8/8, Test Error= 0.210304388179
# [array(0.9098620517604792), array(0.9651472466523909)]
# Testing Score= 0.937504649206
# Epoch 351, Minibatch 8/8, Test Error= 0.202534920703
# Epoch 352, Minibatch 8/8, Test Error= 0.209141726435
# Epoch 353, Minibatch 8/8, Test Error= 0.208159789187
# Epoch 354, Minibatch 8/8, Test Error= 0.213383947476
# Epoch 355, Minibatch 8/8, Test Error= 0.215730525976
# Epoch 356, Minibatch 8/8, Test Error= 0.211585372104
# Epoch 357, Minibatch 8/8, Test Error= 0.215738718064
# Epoch 358, Minibatch 8/8, Test Error= 0.212055518079
# Epoch 359, Minibatch 8/8, Test Error= 0.212159003589
# Epoch 360, Minibatch 8/8, Test Error= 0.210609087797
# [array(0.9028927574512983), array(0.9802076170349464)]
# Testing Score= 0.941550187243
# Epoch 361, Minibatch 8/8, Test Error= 0.212381087955
# Epoch 362, Minibatch 8/8, Test Error= 0.208311713812
# Epoch 363, Minibatch 8/8, Test Error= 0.215321514307
# Epoch 364, Minibatch 8/8, Test Error= 0.210587973637
# Epoch 365, Minibatch 8/8, Test Error= 0.206343820227
# Epoch 366, Minibatch 8/8, Test Error= 0.213277007816
# Epoch 367, Minibatch 8/8, Test Error= 0.210054363096
# Epoch 368, Minibatch 8/8, Test Error= 0.214779609451
# Epoch 369, Minibatch 8/8, Test Error= 0.215056362376
# Epoch 370, Minibatch 8/8, Test Error= 0.214544188149
# [array(0.9096360397094962), array(0.9743915793057157)]
# Testing Score= 0.942013809508
# Epoch 371, Minibatch 8/8, Test Error= 0.206355597481
# Epoch 372, Minibatch 8/8, Test Error= 0.20614511878
# Epoch 373, Minibatch 8/8, Test Error= 0.212884060473
# Epoch 374, Minibatch 8/8, Test Error= 0.209057022266
# Epoch 375, Minibatch 8/8, Test Error= 0.207804364153
# Epoch 376, Minibatch 8/8, Test Error= 0.215559183992
# Epoch 377, Minibatch 8/8, Test Error= 0.209376365149
# Epoch 378, Minibatch 8/8, Test Error= 0.217096257338
# Epoch 379, Minibatch 8/8, Test Error= 0.20790115277
# Epoch 380, Minibatch 8/8, Test Error= 0.20850786967
# [array(0.9040496302705299), array(0.9759684515709894)]
# Testing Score= 0.940009040921
# Epoch 381, Minibatch 8/8, Test Error= 0.2066822956
# Epoch 382, Minibatch 8/8, Test Error= 0.213304238897
# Epoch 383, Minibatch 8/8, Test Error= 0.212296714349
# Epoch 384, Minibatch 8/8, Test Error= 0.208209424223
# Epoch 385, Minibatch 8/8, Test Error= 0.20925023062
# Epoch 386, Minibatch 8/8, Test Error= 0.207361951098
# Epoch 387, Minibatch 8/8, Test Error= 0.21662153339
# Epoch 388, Minibatch 8/8, Test Error= 0.209780481463
# Epoch 389, Minibatch 8/8, Test Error= 0.206448947992
# Epoch 390, Minibatch 8/8, Test Error= 0.216212752536
# [array(0.912444318287088), array(0.970067694723156)]
# Testing Score= 0.941256006505
# Epoch 391, Minibatch 8/8, Test Error= 0.212637468379
# Epoch 392, Minibatch 8/8, Test Error= 0.208391826797
# Epoch 393, Minibatch 8/8, Test Error= 0.210288826398
# Epoch 394, Minibatch 8/8, Test Error= 0.210374169652
# Epoch 395, Minibatch 8/8, Test Error= 0.20408658146
# Epoch 396, Minibatch 8/8, Test Error= 0.210265608198
# Epoch 397, Minibatch 8/8, Test Error= 0.217073579074
# Epoch 398, Minibatch 8/8, Test Error= 0.214110114474
# Epoch 399, Minibatch 8/8, Test Error= 0.208870637334
# Epoch 400, Minibatch 8/8, Test Error= 0.209889607508
# [array(0.9057365766798637), array(0.9640363783361664)]
# Testing Score= 0.934886477508
# Epoch 401, Minibatch 8/8, Test Error= 0.21273076089
# Epoch 402, Minibatch 8/8, Test Error= 0.2055262748
# Epoch 403, Minibatch 8/8, Test Error= 0.207959063096
# Epoch 404, Minibatch 8/8, Test Error= 0.21224885773
# Epoch 405, Minibatch 8/8, Test Error= 0.2109406649
# Epoch 406, Minibatch 8/8, Test Error= 0.209482507654
# Epoch 407, Minibatch 8/8, Test Error= 0.207158578842
# Epoch 408, Minibatch 8/8, Test Error= 0.208649336904
# Epoch 409, Minibatch 8/8, Test Error= 0.211963356913
# Epoch 410, Minibatch 8/8, Test Error= 0.209883051964
# [array(0.9156078178091628), array(0.9585295522999069)]
# Testing Score= 0.937068685055
# Epoch 411, Minibatch 8/8, Test Error= 0.205608923548
# Epoch 412, Minibatch 8/8, Test Error= 0.210313663244
# Epoch 413, Minibatch 8/8, Test Error= 0.208216898928
# Epoch 414, Minibatch 8/8, Test Error= 0.209789756129
# Epoch 415, Minibatch 8/8, Test Error= 0.214679251635
# Epoch 416, Minibatch 8/8, Test Error= 0.205576833356
# Epoch 417, Minibatch 8/8, Test Error= 0.209430553547
# Epoch 418, Minibatch 8/8, Test Error= 0.210446707278
# Epoch 419, Minibatch 8/8, Test Error= 0.216949372547
# Epoch 420, Minibatch 8/8, Test Error= 0.213392052354
# [array(0.9147611263261923), array(0.96383179742596)]
# Testing Score= 0.939296461876
# Epoch 421, Minibatch 8/8, Test Error= 0.209054739401
# Epoch 422, Minibatch 8/8, Test Error= 0.208092760103
# Epoch 423, Minibatch 8/8, Test Error= 0.207614979294
# Epoch 424, Minibatch 8/8, Test Error= 0.211902629555
# Epoch 425, Minibatch 8/8, Test Error= 0.208145014346
# Epoch 426, Minibatch 8/8, Test Error= 0.20687394021
# Epoch 427, Minibatch 8/8, Test Error= 0.205308180535
# Epoch 428, Minibatch 8/8, Test Error= 0.207591566486
# Epoch 429, Minibatch 8/8, Test Error= 0.205987050048
# Epoch 430, Minibatch 8/8, Test Error= 0.205952326056
# [array(0.8976259047791693), array(0.9823312055101405)]
# Testing Score= 0.939978555145
# Epoch 431, Minibatch 8/8, Test Error= 0.206956313347
# Epoch 432, Minibatch 8/8, Test Error= 0.208827277017
# Epoch 433, Minibatch 8/8, Test Error= 0.212181286627
# Epoch 434, Minibatch 8/8, Test Error= 0.208954653688
# Epoch 435, Minibatch 8/8, Test Error= 0.21282687106
# Epoch 436, Minibatch 8/8, Test Error= 0.208619794989
# Epoch 437, Minibatch 8/8, Test Error= 0.203776300014
# Epoch 438, Minibatch 8/8, Test Error= 0.20879514046
# Epoch 439, Minibatch 8/8, Test Error= 0.209730726848
# Epoch 440, Minibatch 8/8, Test Error= 0.207903673369
# [array(0.9055468463978776), array(0.9621885910348112)]
# Testing Score= 0.933867718716
# Epoch 441, Minibatch 8/8, Test Error= 0.207858244535
# Epoch 442, Minibatch 8/8, Test Error= 0.207414692975
# Epoch 443, Minibatch 8/8, Test Error= 0.205921616972
# Epoch 444, Minibatch 8/8, Test Error= 0.20561021851
# Epoch 445, Minibatch 8/8, Test Error= 0.209203243858
# Epoch 446, Minibatch 8/8, Test Error= 0.202262587319
# Epoch 447, Minibatch 8/8, Test Error= 0.21003593795
# Epoch 448, Minibatch 8/8, Test Error= 0.209388358976
# Epoch 449, Minibatch 8/8, Test Error= 0.207945746744
# Epoch 450, Minibatch 8/8, Test Error= 0.207059325182
# [array(0.9128265955052568), array(0.9641423808315557)]
# Testing Score= 0.938484488168
# Epoch 451, Minibatch 8/8, Test Error= 0.201530991759
# Epoch 452, Minibatch 8/8, Test Error= 0.203618941442
# Epoch 453, Minibatch 8/8, Test Error= 0.207140727929
# Epoch 454, Minibatch 8/8, Test Error= 0.211874104934
# Epoch 455, Minibatch 8/8, Test Error= 0.208360056432
# Epoch 456, Minibatch 8/8, Test Error= 0.207906283826
# Epoch 457, Minibatch 8/8, Test Error= 0.213231728959
# Epoch 458, Minibatch 8/8, Test Error= 0.209519840679
# Epoch 459, Minibatch 8/8, Test Error= 0.209179747133
# Epoch 460, Minibatch 8/8, Test Error= 0.206001447032
# [array(0.9102809791666084), array(0.9669254072536801)]
# Testing Score= 0.93860319321
# Epoch 461, Minibatch 8/8, Test Error= 0.205479037296
# Epoch 462, Minibatch 8/8, Test Error= 0.203793881714
# Epoch 463, Minibatch 8/8, Test Error= 0.212547711263
# Epoch 464, Minibatch 8/8, Test Error= 0.209506215755
# Epoch 465, Minibatch 8/8, Test Error= 0.205844175461
# Epoch 466, Minibatch 8/8, Test Error= 0.209889451938
# Epoch 467, Minibatch 8/8, Test Error= 0.204605268567
# Epoch 468, Minibatch 8/8, Test Error= 0.206060908113
# Epoch 469, Minibatch 8/8, Test Error= 0.205211306218
# Epoch 470, Minibatch 8/8, Test Error= 0.208025451138
# [array(0.9110932900699513), array(0.9657622398133793)]
# Testing Score= 0.938427764942
# Epoch 471, Minibatch 8/8, Test Error= 0.207923821093
# Epoch 472, Minibatch 8/8, Test Error= 0.205155417798
# Epoch 473, Minibatch 8/8, Test Error= 0.209407317484
# Epoch 474, Minibatch 8/8, Test Error= 0.208817964726
# Epoch 475, Minibatch 8/8, Test Error= 0.206841388107
# Epoch 476, Minibatch 8/8, Test Error= 0.207601168517
# Epoch 477, Minibatch 8/8, Test Error= 0.201903516781
# Epoch 478, Minibatch 8/8, Test Error= 0.204869740122
# Epoch 479, Minibatch 8/8, Test Error= 0.210110917611
# Epoch 480, Minibatch 8/8, Test Error= 0.208131562862
# [array(0.9106674757734179), array(0.9636018576066355)]
# Testing Score= 0.93713466669
# Epoch 481, Minibatch 8/8, Test Error= 0.210982958089
# Epoch 482, Minibatch 8/8, Test Error= 0.208473876938
# Epoch 483, Minibatch 8/8, Test Error= 0.206760093457
# Epoch 484, Minibatch 8/8, Test Error= 0.208701466287
# Epoch 485, Minibatch 8/8, Test Error= 0.203220243333
# Epoch 486, Minibatch 8/8, Test Error= 0.203499632855
# Epoch 487, Minibatch 8/8, Test Error= 0.204731574187
# Epoch 488, Minibatch 8/8, Test Error= 0.206134407495
# Epoch 489, Minibatch 8/8, Test Error= 0.21024152211
# Epoch 490, Minibatch 8/8, Test Error= 0.209643934109
# [array(0.9020760472529312), array(0.9712352869861196)]
# Testing Score= 0.93665566712
# Epoch 491, Minibatch 8/8, Test Error= 0.205644910161
# Epoch 492, Minibatch 8/8, Test Error= 0.205114742394
# Epoch 493, Minibatch 8/8, Test Error= 0.204123708495
# Epoch 494, Minibatch 8/8, Test Error= 0.201275598036
# Epoch 495, Minibatch 8/8, Test Error= 0.206044165951
# Epoch 496, Minibatch 8/8, Test Error= 0.203360744345
# Epoch 497, Minibatch 8/8, Test Error= 0.202250866248
# Epoch 498, Minibatch 8/8, Test Error= 0.206160128842
# Epoch 499, Minibatch 8/8, Test Error= 0.205487992738
# Epoch 500, Minibatch 8/8, Test Error= 0.202391152989
# [array(0.9071337294048514), array(0.9625565354237999)]
# Testing Score= 0.934845132414
# Epoch 501, Minibatch 8/8, Test Error= 0.20579622908
# Epoch 502, Minibatch 8/8, Test Error= 0.203492113553
# Epoch 503, Minibatch 8/8, Test Error= 0.208071498145
# Epoch 504, Minibatch 8/8, Test Error= 0.207995624182
# Epoch 505, Minibatch 8/8, Test Error= 0.204208241755
# Epoch 506, Minibatch 8/8, Test Error= 0.204700720652
# Epoch 507, Minibatch 8/8, Test Error= 0.203820068845
# Epoch 508, Minibatch 8/8, Test Error= 0.201355604515
# Epoch 509, Minibatch 8/8, Test Error= 0.204569071366
# Epoch 510, Minibatch 8/8, Test Error= 0.201378944204
# [array(0.9129527699779627), array(0.958107824485138)]
# Testing Score= 0.935530297232
# Epoch 511, Minibatch 8/8, Test Error= 0.202923502749
# Epoch 512, Minibatch 8/8, Test Error= 0.201154271196
# Epoch 513, Minibatch 8/8, Test Error= 0.204338254404
# Epoch 514, Minibatch 8/8, Test Error= 0.200335537808
# Epoch 515, Minibatch 8/8, Test Error= 0.207213675962
# Epoch 516, Minibatch 8/8, Test Error= 0.21022979033
# Epoch 517, Minibatch 8/8, Test Error= 0.201031987464
# Epoch 518, Minibatch 8/8, Test Error= 0.205282957059
# Epoch 519, Minibatch 8/8, Test Error= 0.207526774399
# Epoch 520, Minibatch 8/8, Test Error= 0.206529332856
# [array(0.907165964133425), array(0.9675722253090214)]
# Testing Score= 0.937369094721
# Epoch 521, Minibatch 8/8, Test Error= 0.203137987541
# Epoch 522, Minibatch 8/8, Test Error= 0.205807111942
# Epoch 523, Minibatch 8/8, Test Error= 0.205370220805
# Epoch 524, Minibatch 8/8, Test Error= 0.211137053838
# Epoch 525, Minibatch 8/8, Test Error= 0.206432726183
# Epoch 526, Minibatch 8/8, Test Error= 0.205773604396
# Epoch 527, Minibatch 8/8, Test Error= 0.205374445978
# Epoch 528, Minibatch 8/8, Test Error= 0.202708429742
# Epoch 529, Minibatch 8/8, Test Error= 0.202478889391
# Epoch 530, Minibatch 8/8, Test Error= 0.205101490644
# [array(0.910126138446517), array(0.9669026569990258)]
# Testing Score= 0.938514397723
# Epoch 531, Minibatch 8/8, Test Error= 0.203048187263
# Epoch 532, Minibatch 8/8, Test Error= 0.202006026963
# Epoch 533, Minibatch 8/8, Test Error= 0.203755983252
# Epoch 534, Minibatch 8/8, Test Error= 0.203875369615
# Epoch 535, Minibatch 8/8, Test Error= 0.202159590891
# Epoch 536, Minibatch 8/8, Test Error= 0.204011108372
# Epoch 537, Minibatch 8/8, Test Error= 0.2058009684
# Epoch 538, Minibatch 8/8, Test Error= 0.20410483725
# Epoch 539, Minibatch 8/8, Test Error= 0.209370165625
# Epoch 540, Minibatch 8/8, Test Error= 0.204886327127
# [array(0.9092122650031916), array(0.9662070624209189)]
# Testing Score= 0.937709663712
# Epoch 541, Minibatch 8/8, Test Error= 0.203440603677
# Epoch 542, Minibatch 8/8, Test Error= 0.202505154758
# Epoch 543, Minibatch 8/8, Test Error= 0.206603838967
# Epoch 544, Minibatch 8/8, Test Error= 0.20588422048
# Epoch 545, Minibatch 8/8, Test Error= 0.204325678328
# Epoch 546, Minibatch 8/8, Test Error= 0.204858506554
# Epoch 547, Minibatch 8/8, Test Error= 0.205782069197
# Epoch 548, Minibatch 8/8, Test Error= 0.20484513
# Epoch 549, Minibatch 8/8, Test Error= 0.202038577266
# Epoch 550, Minibatch 8/8, Test Error= 0.205219515243
# [array(0.9068888616046177), array(0.9591366272107328)]
# Testing Score= 0.933012744408
# Epoch 551, Minibatch 8/8, Test Error= 0.204300247104
# Epoch 552, Minibatch 8/8, Test Error= 0.199170185508
# Epoch 553, Minibatch 8/8, Test Error= 0.209554887281
# Epoch 554, Minibatch 8/8, Test Error= 0.20607693086
# Epoch 555, Minibatch 8/8, Test Error= 0.208575030621
# Epoch 556, Minibatch 8/8, Test Error= 0.205151169172
# Epoch 557, Minibatch 8/8, Test Error= 0.203138749484
# Epoch 558, Minibatch 8/8, Test Error= 0.206033416966
# Epoch 559, Minibatch 8/8, Test Error= 0.201137872665
# Epoch 560, Minibatch 8/8, Test Error= 0.203818324506
# [array(0.9122981765599143), array(0.9588483565219933)]
# Testing Score= 0.935573266541
# Epoch 561, Minibatch 8/8, Test Error= 0.205499974624
# Epoch 562, Minibatch 8/8, Test Error= 0.200097188431
# Epoch 563, Minibatch 8/8, Test Error= 0.206794396577
# Epoch 564, Minibatch 8/8, Test Error= 0.20211868233
# Epoch 565, Minibatch 8/8, Test Error= 0.198245698523
# Epoch 566, Minibatch 8/8, Test Error= 0.20267704667
# Epoch 567, Minibatch 8/8, Test Error= 0.20208954429
# Epoch 568, Minibatch 8/8, Test Error= 0.203306856221
# Epoch 569, Minibatch 8/8, Test Error= 0.205677324755
# Epoch 570, Minibatch 8/8, Test Error= 0.200943838318
# [array(0.9113814997009765), array(0.9557683383202809)]
# Testing Score= 0.933574919011
# Epoch 571, Minibatch 8/8, Test Error= 0.203700200525
# Epoch 572, Minibatch 8/8, Test Error= 0.202209856859
# Epoch 573, Minibatch 8/8, Test Error= 0.202006589515
# Epoch 574, Minibatch 8/8, Test Error= 0.203508339319
# Epoch 575, Minibatch 8/8, Test Error= 0.202907200427
# Epoch 576, Minibatch 8/8, Test Error= 0.203812823177
# Epoch 577, Minibatch 8/8, Test Error= 0.205065412606
# Epoch 578, Minibatch 8/8, Test Error= 0.203392409296
# Epoch 579, Minibatch 8/8, Test Error= 0.207641539118
# Epoch 580, Minibatch 8/8, Test Error= 0.205863691953
# [array(0.9137815248506047), array(0.963601466206458)]
# Testing Score= 0.938691495529
# Epoch 581, Minibatch 8/8, Test Error= 0.205862694587
# Epoch 582, Minibatch 8/8, Test Error= 0.206146993556
# Epoch 583, Minibatch 8/8, Test Error= 0.204310986033
# Epoch 584, Minibatch 8/8, Test Error= 0.205513606312
# Epoch 585, Minibatch 8/8, Test Error= 0.201498975956
# Epoch 586, Minibatch 8/8, Test Error= 0.205460163864
# Epoch 587, Minibatch 8/8, Test Error= 0.206113975383
# Epoch 588, Minibatch 8/8, Test Error= 0.203352864571
# Epoch 589, Minibatch 8/8, Test Error= 0.200069704955
# Epoch 590, Minibatch 8/8, Test Error= 0.203129205322
# [array(0.9071075431950224), array(0.9633476502200221)]
# Testing Score= 0.935227596708
# Epoch 591, Minibatch 8/8, Test Error= 0.204128395585
# Epoch 592, Minibatch 8/8, Test Error= 0.203781871626
# Epoch 593, Minibatch 8/8, Test Error= 0.206111104807
# Epoch 594, Minibatch 8/8, Test Error= 0.204216331982
# Epoch 595, Minibatch 8/8, Test Error= 0.204687424711
# Epoch 596, Minibatch 8/8, Test Error= 0.204171749245
# Epoch 597, Minibatch 8/8, Test Error= 0.205356122782
# Epoch 598, Minibatch 8/8, Test Error= 0.204666187858
# Epoch 599, Minibatch 8/8, Test Error= 0.200191993338
# Epoch 600, Minibatch 8/8, Test Error= 0.202787018337
# [array(0.9107473884864552), array(0.9655297905605871)]
# Testing Score= 0.938138589524
# Epoch 601, Minibatch 8/8, Test Error= 0.203592511363
# Epoch 602, Minibatch 8/8, Test Error= 0.204035405618
# Epoch 603, Minibatch 8/8, Test Error= 0.202780483972
# Epoch 604, Minibatch 8/8, Test Error= 0.208312212443
# Epoch 605, Minibatch 8/8, Test Error= 0.203147295932
# Epoch 606, Minibatch 8/8, Test Error= 0.207195657005
# Epoch 607, Minibatch 8/8, Test Error= 0.200560906369
# Epoch 608, Minibatch 8/8, Test Error= 0.201148675659
# Epoch 609, Minibatch 8/8, Test Error= 0.205305461881
# Epoch 610, Minibatch 8/8, Test Error= 0.201330528714
# [array(0.9084547809522897), array(0.9721708201395962)]
# Testing Score= 0.940312800546
# Epoch 611, Minibatch 8/8, Test Error= 0.200809474523
# Epoch 612, Minibatch 8/8, Test Error= 0.205702320597
# Epoch 613, Minibatch 8/8, Test Error= 0.202187773009
# Epoch 614, Minibatch 8/8, Test Error= 0.204580204375
# Epoch 615, Minibatch 8/8, Test Error= 0.200506370614
# Epoch 616, Minibatch 8/8, Test Error= 0.20111424299
# Epoch 617, Minibatch 8/8, Test Error= 0.20341968767
# Epoch 618, Minibatch 8/8, Test Error= 0.203279405574
# Epoch 619, Minibatch 8/8, Test Error= 0.201510551259
# Epoch 620, Minibatch 8/8, Test Error= 0.206045895026
# [array(0.9115866122306873), array(0.9637679028555386)]
# Testing Score= 0.937677257543
# Epoch 621, Minibatch 8/8, Test Error= 0.205924237758
# Epoch 622, Minibatch 8/8, Test Error= 0.204766570968
# Epoch 623, Minibatch 8/8, Test Error= 0.202270332452
# Epoch 624, Minibatch 8/8, Test Error= 0.199086108708
# Epoch 625, Minibatch 8/8, Test Error= 0.199452183257
# Epoch 626, Minibatch 8/8, Test Error= 0.203892044141
# Epoch 627, Minibatch 8/8, Test Error= 0.204606788062
# Epoch 628, Minibatch 8/8, Test Error= 0.20227895791
# Epoch 629, Minibatch 8/8, Test Error= 0.204284824935
# Epoch 630, Minibatch 8/8, Test Error= 0.200249038761
# [array(0.9100385774945018), array(0.9647444373840202)]
# Testing Score= 0.937391507439
# Epoch 631, Minibatch 8/8, Test Error= 0.203269524588
# Epoch 632, Minibatch 8/8, Test Error= 0.204615668393
# Epoch 633, Minibatch 8/8, Test Error= 0.205310564531
# Epoch 634, Minibatch 8/8, Test Error= 0.202159118366
# Epoch 635, Minibatch 8/8, Test Error= 0.207227010326
# Epoch 636, Minibatch 8/8, Test Error= 0.204329484083
# Epoch 637, Minibatch 8/8, Test Error= 0.198939000519
# Epoch 638, Minibatch 8/8, Test Error= 0.208983530366
# Epoch 639, Minibatch 8/8, Test Error= 0.206216809071
# Epoch 640, Minibatch 8/8, Test Error= 0.204611664942
# [array(0.9096670204889413), array(0.9636592430960954)]
# Testing Score= 0.936663131793
# Epoch 641, Minibatch 8/8, Test Error= 0.204278202348
# Epoch 642, Minibatch 8/8, Test Error= 0.200031645879
# Epoch 643, Minibatch 8/8, Test Error= 0.205315624667
# Epoch 644, Minibatch 8/8, Test Error= 0.203540053144
# Epoch 645, Minibatch 8/8, Test Error= 0.198888627551
# Epoch 646, Minibatch 8/8, Test Error= 0.209957334177
# Epoch 647, Minibatch 8/8, Test Error= 0.200661611865
# Epoch 648, Minibatch 8/8, Test Error= 0.205572025829
# Epoch 649, Minibatch 8/8, Test Error= 0.202497306247
# Epoch 650, Minibatch 8/8, Test Error= 0.202025310379
# [array(0.9029210069655136), array(0.9691047078464294)]
# Testing Score= 0.936012857406
# Epoch 651, Minibatch 8/8, Test Error= 0.199111207703
# Epoch 652, Minibatch 8/8, Test Error= 0.204775640403
# Epoch 653, Minibatch 8/8, Test Error= 0.201212753374
# Epoch 654, Minibatch 8/8, Test Error= 0.1990118642
# Epoch 655, Minibatch 8/8, Test Error= 0.202799382513
# Epoch 656, Minibatch 8/8, Test Error= 0.202994307635
# Epoch 657, Minibatch 8/8, Test Error= 0.204659033337
# Epoch 658, Minibatch 8/8, Test Error= 0.202008349809
# Epoch 659, Minibatch 8/8, Test Error= 0.203140798089
# Epoch 660, Minibatch 8/8, Test Error= 0.203398622675
# [array(0.903969277677129), array(0.9700971754002344)]
# Testing Score= 0.937033226539
# Epoch 661, Minibatch 8/8, Test Error= 0.200129972591
# Epoch 662, Minibatch 8/8, Test Error= 0.203511273004
# Epoch 663, Minibatch 8/8, Test Error= 0.202127371094
# Epoch 664, Minibatch 8/8, Test Error= 0.199381580892
# Epoch 665, Minibatch 8/8, Test Error= 0.198962509605
# Epoch 666, Minibatch 8/8, Test Error= 0.202420696745
# Epoch 667, Minibatch 8/8, Test Error= 0.202505289888
# Epoch 668, Minibatch 8/8, Test Error= 0.206748895204
# Epoch 669, Minibatch 8/8, Test Error= 0.202717390035
# Epoch 670, Minibatch 8/8, Test Error= 0.202339412379
# [array(0.9085522265390915), array(0.9674929043080411)]
# Testing Score= 0.938022565424
# Epoch 671, Minibatch 8/8, Test Error= 0.201303941655
# Epoch 672, Minibatch 8/8, Test Error= 0.205585760175
# Epoch 673, Minibatch 8/8, Test Error= 0.201316882502
# Epoch 674, Minibatch 8/8, Test Error= 0.200139219872
# Epoch 675, Minibatch 8/8, Test Error= 0.203897975744
# Epoch 676, Minibatch 8/8, Test Error= 0.200916590082
# Epoch 677, Minibatch 8/8, Test Error= 0.202027092863
# Epoch 678, Minibatch 8/8, Test Error= 0.202832985797
# Epoch 679, Minibatch 8/8, Test Error= 0.19805663588
# Epoch 680, Minibatch 8/8, Test Error= 0.200300881374
# [array(0.9097975622217515), array(0.9573638128694949)]
# Testing Score= 0.933580687546
# Epoch 681, Minibatch 8/8, Test Error= 0.201410205478
# Epoch 682, Minibatch 8/8, Test Error= 0.202869359288
# Epoch 683, Minibatch 8/8, Test Error= 0.202765225491
# Epoch 684, Minibatch 8/8, Test Error= 0.205479659808
# Epoch 685, Minibatch 8/8, Test Error= 0.200247681683
# Epoch 686, Minibatch 8/8, Test Error= 0.201655719366
# Epoch 687, Minibatch 8/8, Test Error= 0.20137418774
# Epoch 688, Minibatch 8/8, Test Error= 0.202367746461
# Epoch 689, Minibatch 8/8, Test Error= 0.203006843856
# Epoch 690, Minibatch 8/8, Test Error= 0.204060880987
# [array(0.9132543018830035), array(0.9589248359678699)]
# Testing Score= 0.936089568925
# Epoch 691, Minibatch 8/8, Test Error= 0.204337935617
# Epoch 692, Minibatch 8/8, Test Error= 0.203072744992
# Epoch 693, Minibatch 8/8, Test Error= 0.203103264065
# Epoch 694, Minibatch 8/8, Test Error= 0.203451400215
# Epoch 695, Minibatch 8/8, Test Error= 0.199587875096
# Epoch 696, Minibatch 8/8, Test Error= 0.202979198018
# Epoch 697, Minibatch 8/8, Test Error= 0.201985263161
# Epoch 698, Minibatch 8/8, Test Error= 0.199846044264
# Epoch 699, Minibatch 8/8, Test Error= 0.196472116649
# Epoch 700, Minibatch 8/8, Test Error= 0.199966185591
# [array(0.9107848894901472), array(0.9621721189661006)]
# Testing Score= 0.936478504228
# Epoch 701, Minibatch 8/8, Test Error= 0.202078118967
# Epoch 702, Minibatch 8/8, Test Error= 0.198405492542
# Epoch 703, Minibatch 8/8, Test Error= 0.20193722452
# Epoch 704, Minibatch 8/8, Test Error= 0.199776150011
# Epoch 705, Minibatch 8/8, Test Error= 0.201898737903
# Epoch 706, Minibatch 8/8, Test Error= 0.199533313967
# Epoch 707, Minibatch 8/8, Test Error= 0.20639651915
# Epoch 708, Minibatch 8/8, Test Error= 0.203016269249
# Epoch 709, Minibatch 8/8, Test Error= 0.203272780458
# Epoch 710, Minibatch 8/8, Test Error= 0.204030682246
# [array(0.9104525258874838), array(0.9631440544225456)]
# Testing Score= 0.936798290155
# Epoch 711, Minibatch 8/8, Test Error= 0.201309119554
# Epoch 712, Minibatch 8/8, Test Error= 0.202275181106
# Epoch 713, Minibatch 8/8, Test Error= 0.200387738116
# Epoch 714, Minibatch 8/8, Test Error= 0.203507904957
# Epoch 715, Minibatch 8/8, Test Error= 0.204668519982
# Epoch 716, Minibatch 8/8, Test Error= 0.201777862019
# Epoch 717, Minibatch 8/8, Test Error= 0.197600016954
# Epoch 718, Minibatch 8/8, Test Error= 0.197493523587
# Epoch 719, Minibatch 8/8, Test Error= 0.203007727696
# Epoch 720, Minibatch 8/8, Test Error= 0.202097548283
# [array(0.9139986441604689), array(0.9601867060281494)]
# Testing Score= 0.937092675094
# Epoch 721, Minibatch 8/8, Test Error= 0.200838187814
# Epoch 722, Minibatch 8/8, Test Error= 0.203931641525
# Epoch 723, Minibatch 8/8, Test Error= 0.203217091985
# Epoch 724, Minibatch 8/8, Test Error= 0.201229240211
# Epoch 725, Minibatch 8/8, Test Error= 0.201443125519
# Epoch 726, Minibatch 8/8, Test Error= 0.20249514791
# Epoch 727, Minibatch 8/8, Test Error= 0.198562537817
# Epoch 728, Minibatch 8/8, Test Error= 0.201783580065
# Epoch 729, Minibatch 8/8, Test Error= 0.203395620592
# Epoch 730, Minibatch 8/8, Test Error= 0.201947237397
# [array(0.9116351450348633), array(0.9611804298445008)]
# Testing Score= 0.93640778744
# Epoch 731, Minibatch 8/8, Test Error= 0.201972778824
# Epoch 732, Minibatch 8/8, Test Error= 0.199887920946
# Epoch 733, Minibatch 8/8, Test Error= 0.197613062786
# Epoch 734, Minibatch 8/8, Test Error= 0.200806089393
# Epoch 735, Minibatch 8/8, Test Error= 0.203542576782
# Epoch 736, Minibatch 8/8, Test Error= 0.200783097113
# Epoch 737, Minibatch 8/8, Test Error= 0.202415372087
# Epoch 738, Minibatch 8/8, Test Error= 0.199450783784
# Epoch 739, Minibatch 8/8, Test Error= 0.200526155845
# Epoch 740, Minibatch 8/8, Test Error= 0.201061353277
# [array(0.9041457320039538), array(0.9623725473482878)]
# Testing Score= 0.933259139676
# Epoch 741, Minibatch 8/8, Test Error= 0.198697324076
# Epoch 742, Minibatch 8/8, Test Error= 0.199365402513
# Epoch 743, Minibatch 8/8, Test Error= 0.200848504967
# Epoch 744, Minibatch 8/8, Test Error= 0.199224256361
# Epoch 745, Minibatch 8/8, Test Error= 0.201057677343
# Epoch 746, Minibatch 8/8, Test Error= 0.202838467242
# Epoch 747, Minibatch 8/8, Test Error= 0.202280626612
# Epoch 748, Minibatch 8/8, Test Error= 0.203074727716
# Epoch 749, Minibatch 8/8, Test Error= 0.199220029985
# Epoch 750, Minibatch 8/8, Test Error= 0.201968608066
# [array(0.9059129398498287), array(0.9715078507343813)]
# Testing Score= 0.938710395292
# Epoch 751, Minibatch 8/8, Test Error= 0.198296385116
# Epoch 752, Minibatch 8/8, Test Error= 0.202144504113
# Epoch 753, Minibatch 8/8, Test Error= 0.20211693428
# Epoch 754, Minibatch 8/8, Test Error= 0.197313804491
# Epoch 755, Minibatch 8/8, Test Error= 0.196380805011
# Epoch 756, Minibatch 8/8, Test Error= 0.198969601344
# Epoch 757, Minibatch 8/8, Test Error= 0.198395568735
# Epoch 758, Minibatch 8/8, Test Error= 0.203151593548
# Epoch 759, Minibatch 8/8, Test Error= 0.200223806838
# Epoch 760, Minibatch 8/8, Test Error= 0.199620134985
# [array(0.9097173101755989), array(0.9632084390465329)]
# Testing Score= 0.936462874611
# Epoch 761, Minibatch 8/8, Test Error= 0.201381823406
# Epoch 762, Minibatch 8/8, Test Error= 0.199126283077
# Epoch 763, Minibatch 8/8, Test Error= 0.199313635101
# Epoch 764, Minibatch 8/8, Test Error= 0.204063536503
# Epoch 765, Minibatch 8/8, Test Error= 0.200855781022
# Epoch 766, Minibatch 8/8, Test Error= 0.204215952912
# Epoch 767, Minibatch 8/8, Test Error= 0.194287851546
# Epoch 768, Minibatch 8/8, Test Error= 0.198727042238
# Epoch 769, Minibatch 8/8, Test Error= 0.202346898734
# Epoch 770, Minibatch 8/8, Test Error= 0.199622411595
# [array(0.9111983344417427), array(0.9666366679181108)]
# Testing Score= 0.93891750118
# Epoch 771, Minibatch 8/8, Test Error= 0.199937625137
# Epoch 772, Minibatch 8/8, Test Error= 0.201995146905
# Epoch 773, Minibatch 8/8, Test Error= 0.202220391556
# Epoch 774, Minibatch 8/8, Test Error= 0.196015442376
# Epoch 775, Minibatch 8/8, Test Error= 0.197542795245
# Epoch 776, Minibatch 8/8, Test Error= 0.198435267138
# Epoch 777, Minibatch 8/8, Test Error= 0.198889194926
# Epoch 778, Minibatch 8/8, Test Error= 0.197888417164
# Epoch 779, Minibatch 8/8, Test Error= 0.197454050074
# Epoch 780, Minibatch 8/8, Test Error= 0.201978456114
# [array(0.9099313640608223), array(0.962194620991507)]
# Testing Score= 0.936062992526
# Epoch 781, Minibatch 8/8, Test Error= 0.198358898733
# Epoch 782, Minibatch 8/8, Test Error= 0.200351906193
# Epoch 783, Minibatch 8/8, Test Error= 0.195667507934
# Epoch 784, Minibatch 8/8, Test Error= 0.199133443097
# Epoch 785, Minibatch 8/8, Test Error= 0.197569628584
# Epoch 786, Minibatch 8/8, Test Error= 0.201281680049
# Epoch 787, Minibatch 8/8, Test Error= 0.203045371972
# Epoch 788, Minibatch 8/8, Test Error= 0.201091686512
# Epoch 789, Minibatch 8/8, Test Error= 0.19857324516
# Epoch 790, Minibatch 8/8, Test Error= 0.200709621988
# [array(0.9126356503304773), array(0.9522667677625611)]
# Testing Score= 0.932451209047
# Epoch 791, Minibatch 8/8, Test Error= 0.195392799153
# Epoch 792, Minibatch 8/8, Test Error= 0.198764166016
# Epoch 793, Minibatch 8/8, Test Error= 0.198851965022
# Epoch 794, Minibatch 8/8, Test Error= 0.198756111504
# Epoch 795, Minibatch 8/8, Test Error= 0.199219922031
# Epoch 796, Minibatch 8/8, Test Error= 0.198390708181
# Epoch 797, Minibatch 8/8, Test Error= 0.202511256552
# Epoch 798, Minibatch 8/8, Test Error= 0.200203776594
# Epoch 799, Minibatch 8/8, Test Error= 0.196957451604
# Epoch 800, Minibatch 8/8, Test Error= 0.198203943854
# [array(0.9141721817708435), array(0.9581900283311962)]
# Testing Score= 0.936181105051
# Epoch 801, Minibatch 8/8, Test Error= 0.200481207705
# Epoch 802, Minibatch 8/8, Test Error= 0.198366907479
# Epoch 803, Minibatch 8/8, Test Error= 0.1990755532
# Epoch 804, Minibatch 8/8, Test Error= 0.202274151113
# Epoch 805, Minibatch 8/8, Test Error= 0.198665556877
# Epoch 806, Minibatch 8/8, Test Error= 0.198549390005
# Epoch 807, Minibatch 8/8, Test Error= 0.202480698952
# Epoch 808, Minibatch 8/8, Test Error= 0.20195140557
# Epoch 809, Minibatch 8/8, Test Error= 0.201617090369
# Epoch 810, Minibatch 8/8, Test Error= 0.201632146986
# [array(0.9026736426698714), array(0.9681483049741425)]
# Testing Score= 0.935410973822
# Epoch 811, Minibatch 8/8, Test Error= 0.199807348001
# Epoch 812, Minibatch 8/8, Test Error= 0.200047826105
# Epoch 813, Minibatch 8/8, Test Error= 0.198698224412
# Epoch 814, Minibatch 8/8, Test Error= 0.20044331843
# Epoch 815, Minibatch 8/8, Test Error= 0.19843454409
# Epoch 816, Minibatch 8/8, Test Error= 0.198686650901
# Epoch 817, Minibatch 8/8, Test Error= 0.199779507253
# Epoch 818, Minibatch 8/8, Test Error= 0.198820028871
# Epoch 819, Minibatch 8/8, Test Error= 0.195744825896
# Epoch 820, Minibatch 8/8, Test Error= 0.197724718444
# [array(0.9107503766455644), array(0.9555988832148298)]
# Testing Score= 0.93317462993
# Epoch 821, Minibatch 8/8, Test Error= 0.198859255428
# Epoch 822, Minibatch 8/8, Test Error= 0.196908240419
# Epoch 823, Minibatch 8/8, Test Error= 0.19959059011
# Epoch 824, Minibatch 8/8, Test Error= 0.201696251524
# Epoch 825, Minibatch 8/8, Test Error= 0.196115876678
# Epoch 826, Minibatch 8/8, Test Error= 0.201983406134
# Epoch 827, Minibatch 8/8, Test Error= 0.202543077748
# Epoch 828, Minibatch 8/8, Test Error= 0.200253756421
# Epoch 829, Minibatch 8/8, Test Error= 0.201980193186
# Epoch 830, Minibatch 8/8, Test Error= 0.197012420572
# [array(0.9102850834688114), array(0.9622127679473932)]
# Testing Score= 0.936248925708
# Epoch 831, Minibatch 8/8, Test Error= 0.197323155734
# Epoch 832, Minibatch 8/8, Test Error= 0.197198842739
# Epoch 833, Minibatch 8/8, Test Error= 0.20047243034
# Epoch 834, Minibatch 8/8, Test Error= 0.203194239259
# Epoch 835, Minibatch 8/8, Test Error= 0.201247205934
# Epoch 836, Minibatch 8/8, Test Error= 0.193887263289
# Epoch 837, Minibatch 8/8, Test Error= 0.198077349705
# Epoch 838, Minibatch 8/8, Test Error= 0.201969951249
# Epoch 839, Minibatch 8/8, Test Error= 0.200839262975
# Epoch 840, Minibatch 8/8, Test Error= 0.199622475788
# [array(0.9062881490554199), array(0.963611147093232)]
# Testing Score= 0.934949648074
# Epoch 841, Minibatch 8/8, Test Error= 0.192350221903
# Epoch 842, Minibatch 8/8, Test Error= 0.198689755967
# Epoch 843, Minibatch 8/8, Test Error= 0.202792427528
# Epoch 844, Minibatch 8/8, Test Error= 0.197777117822
# Epoch 845, Minibatch 8/8, Test Error= 0.200185639038
# Epoch 846, Minibatch 8/8, Test Error= 0.197305127811
# Epoch 847, Minibatch 8/8, Test Error= 0.195129863234
# Epoch 848, Minibatch 8/8, Test Error= 0.198987855618
# Epoch 849, Minibatch 8/8, Test Error= 0.196153154595
# Epoch 850, Minibatch 8/8, Test Error= 0.197629018476
# [array(0.9109780222624708), array(0.9626332174942093)]
# Testing Score= 0.936805619878
# Epoch 851, Minibatch 8/8, Test Error= 0.199552039818
# Epoch 852, Minibatch 8/8, Test Error= 0.201014488519
# Epoch 853, Minibatch 8/8, Test Error= 0.201382262119
# Epoch 854, Minibatch 8/8, Test Error= 0.200102700243
# Epoch 855, Minibatch 8/8, Test Error= 0.197212297678
# Epoch 856, Minibatch 8/8, Test Error= 0.200214384622
# Epoch 857, Minibatch 8/8, Test Error= 0.198966804245
# Epoch 858, Minibatch 8/8, Test Error= 0.201534395812
# Epoch 859, Minibatch 8/8, Test Error= 0.200023933985
# Epoch 860, Minibatch 8/8, Test Error= 0.193329020562
# [array(0.9064447834585907), array(0.9624569234268202)]
# Testing Score= 0.934450853443
# Epoch 861, Minibatch 8/8, Test Error= 0.199959871591
# Epoch 862, Minibatch 8/8, Test Error= 0.194821156103
# Epoch 863, Minibatch 8/8, Test Error= 0.198753728809
# Epoch 864, Minibatch 8/8, Test Error= 0.200621327744
# Epoch 865, Minibatch 8/8, Test Error= 0.200524945856
# Epoch 866, Minibatch 8/8, Test Error= 0.196470512319
# Epoch 867, Minibatch 8/8, Test Error= 0.197807995463
# Epoch 868, Minibatch 8/8, Test Error= 0.200366049957
# Epoch 869, Minibatch 8/8, Test Error= 0.201061836052
# Epoch 870, Minibatch 8/8, Test Error= 0.200987020087
# [array(0.9022198404267077), array(0.9681743487277059)]
# Testing Score= 0.935197094577
# Epoch 871, Minibatch 8/8, Test Error= 0.197708592848
# Epoch 872, Minibatch 8/8, Test Error= 0.199237035329
# Epoch 873, Minibatch 8/8, Test Error= 0.196984273947
# Epoch 874, Minibatch 8/8, Test Error= 0.197630819365
# Epoch 875, Minibatch 8/8, Test Error= 0.199963284539
# Epoch 876, Minibatch 8/8, Test Error= 0.19708181042
# Epoch 877, Minibatch 8/8, Test Error= 0.199363554368
# Epoch 878, Minibatch 8/8, Test Error= 0.200177249613
# Epoch 879, Minibatch 8/8, Test Error= 0.197316826827
# Epoch 880, Minibatch 8/8, Test Error= 0.199295904955
# [array(0.9071820895220674), array(0.9642807878250748)]
# Testing Score= 0.935731438674
# Epoch 881, Minibatch 8/8, Test Error= 0.198500270663
# Epoch 882, Minibatch 8/8, Test Error= 0.197765130718
# Epoch 883, Minibatch 8/8, Test Error= 0.200056429397
# Epoch 884, Minibatch 8/8, Test Error= 0.195528769844
# Epoch 885, Minibatch 8/8, Test Error= 0.199195939763
# Epoch 886, Minibatch 8/8, Test Error= 0.200889282267
# Epoch 887, Minibatch 8/8, Test Error= 0.200746644603
# Epoch 888, Minibatch 8/8, Test Error= 0.200620721987
# Epoch 889, Minibatch 8/8, Test Error= 0.19775647065
# Epoch 890, Minibatch 8/8, Test Error= 0.199538136412
# [array(0.9136938700023925), array(0.9584971521214142)]
# Testing Score= 0.936095511062
# Epoch 891, Minibatch 8/8, Test Error= 0.198321756976
# Epoch 892, Minibatch 8/8, Test Error= 0.196359866587
# Epoch 893, Minibatch 8/8, Test Error= 0.199568976883
# Epoch 894, Minibatch 8/8, Test Error= 0.194197383122
# Epoch 895, Minibatch 8/8, Test Error= 0.201240708154
# Epoch 896, Minibatch 8/8, Test Error= 0.197212141925
# Epoch 897, Minibatch 8/8, Test Error= 0.200038514222
# Epoch 898, Minibatch 8/8, Test Error= 0.198377737835
# Epoch 899, Minibatch 8/8, Test Error= 0.196477665028
# Epoch 900, Minibatch 8/8, Test Error= 0.195976460751
# [array(0.90661909276155), array(0.9624754901119174)]
# Testing Score= 0.934547291437
# Epoch 901, Minibatch 8/8, Test Error= 0.196949427288
# Epoch 902, Minibatch 8/8, Test Error= 0.198529644737
# Epoch 903, Minibatch 8/8, Test Error= 0.201721853024
# Epoch 904, Minibatch 8/8, Test Error= 0.198537303564
# Epoch 905, Minibatch 8/8, Test Error= 0.199780567663
# Epoch 906, Minibatch 8/8, Test Error= 0.194847365868
# Epoch 907, Minibatch 8/8, Test Error= 0.198525187763
# Epoch 908, Minibatch 8/8, Test Error= 0.195004597287
# Epoch 909, Minibatch 8/8, Test Error= 0.197900449812
# Epoch 910, Minibatch 8/8, Test Error= 0.198797855548
# [array(0.9033641199747461), array(0.9683848585375936)]
# Testing Score= 0.935874489256
# Epoch 911, Minibatch 8/8, Test Error= 0.19886035236
# Epoch 912, Minibatch 8/8, Test Error= 0.195461391663
# Epoch 913, Minibatch 8/8, Test Error= 0.19787318956
# Epoch 914, Minibatch 8/8, Test Error= 0.19584899484
# Epoch 915, Minibatch 8/8, Test Error= 0.197518892926
# Epoch 916, Minibatch 8/8, Test Error= 0.197236815673
# Epoch 917, Minibatch 8/8, Test Error= 0.197693015769
# Epoch 918, Minibatch 8/8, Test Error= 0.197714619007
# Epoch 919, Minibatch 8/8, Test Error= 0.200340666984
# Epoch 920, Minibatch 8/8, Test Error= 0.195685191373
# [array(0.9086316456438628), array(0.9637701744159468)]
# Testing Score= 0.93620091003
# Epoch 921, Minibatch 8/8, Test Error= 0.198435119582
# Epoch 922, Minibatch 8/8, Test Error= 0.197833309859
# Epoch 923, Minibatch 8/8, Test Error= 0.196748924414
# Epoch 924, Minibatch 8/8, Test Error= 0.197472475371
# Epoch 925, Minibatch 8/8, Test Error= 0.192849978503
# Epoch 926, Minibatch 8/8, Test Error= 0.198708631785
# Epoch 927, Minibatch 8/8, Test Error= 0.200130444033
# Epoch 928, Minibatch 8/8, Test Error= 0.195191184721
# Epoch 929, Minibatch 8/8, Test Error= 0.201412073699
# Epoch 930, Minibatch 8/8, Test Error= 0.198270936407
# [array(0.9116948905913599), array(0.9581163780501699)]
# Testing Score= 0.934905634321
# Epoch 931, Minibatch 8/8, Test Error= 0.199913767839
# Epoch 932, Minibatch 8/8, Test Error= 0.196339809185
# Epoch 933, Minibatch 8/8, Test Error= 0.19895693017
# Epoch 934, Minibatch 8/8, Test Error= 0.198633925739
# Epoch 935, Minibatch 8/8, Test Error= 0.200250157272
# Epoch 936, Minibatch 8/8, Test Error= 0.196367734998
# Epoch 937, Minibatch 8/8, Test Error= 0.199559999233
# Epoch 938, Minibatch 8/8, Test Error= 0.195486822204
# Epoch 939, Minibatch 8/8, Test Error= 0.198675250628
# Epoch 940, Minibatch 8/8, Test Error= 0.199581444698
# [array(0.90360849370692), array(0.9685870634422653)]
# Testing Score= 0.936097778575
# Epoch 941, Minibatch 8/8, Test Error= 0.196577570728
# Epoch 942, Minibatch 8/8, Test Error= 0.198970488482
# Epoch 943, Minibatch 8/8, Test Error= 0.198574248726
# Epoch 944, Minibatch 8/8, Test Error= 0.198617755557
# Epoch 945, Minibatch 8/8, Test Error= 0.198956048502
# Epoch 946, Minibatch 8/8, Test Error= 0.195485536227
# Epoch 947, Minibatch 8/8, Test Error= 0.196052540574
# Epoch 948, Minibatch 8/8, Test Error= 0.19628804777
# Epoch 949, Minibatch 8/8, Test Error= 0.198195051902
# Epoch 950, Minibatch 8/8, Test Error= 0.198079991529
# [array(0.907429469850117), array(0.963497207204077)]
# Testing Score= 0.935463338527
# Epoch 951, Minibatch 8/8, Test Error= 0.200563422969
# Epoch 952, Minibatch 8/8, Test Error= 0.195589743496
# Epoch 953, Minibatch 8/8, Test Error= 0.195090782654
# Epoch 954, Minibatch 8/8, Test Error= 0.200861867799
# Epoch 955, Minibatch 8/8, Test Error= 0.19536768924
# Epoch 956, Minibatch 8/8, Test Error= 0.193995505905
# Epoch 957, Minibatch 8/8, Test Error= 0.198495395314
# Epoch 958, Minibatch 8/8, Test Error= 0.199314033587
# Epoch 959, Minibatch 8/8, Test Error= 0.197489162643
# Epoch 960, Minibatch 8/8, Test Error= 0.198260093724
# [array(0.9104533132967626), array(0.9567832596541322)]
# Testing Score= 0.933618286475
# Epoch 961, Minibatch 8/8, Test Error= 0.195288922501
# Epoch 962, Minibatch 8/8, Test Error= 0.199552991154
# Epoch 963, Minibatch 8/8, Test Error= 0.198553293465
# Epoch 964, Minibatch 8/8, Test Error= 0.197082018184
# Epoch 965, Minibatch 8/8, Test Error= 0.199113759539
# Epoch 966, Minibatch 8/8, Test Error= 0.193905885486
# Epoch 967, Minibatch 8/8, Test Error= 0.197442433058
# Epoch 968, Minibatch 8/8, Test Error= 0.196750163238
# Epoch 969, Minibatch 8/8, Test Error= 0.196609342993
# Epoch 970, Minibatch 8/8, Test Error= 0.19900926076
# [array(0.906611528037019), array(0.9633778928812966)]
# Testing Score= 0.934994710459
# Epoch 971, Minibatch 8/8, Test Error= 0.195902016266
# Epoch 972, Minibatch 8/8, Test Error= 0.196157516702
# Epoch 973, Minibatch 8/8, Test Error= 0.196789275844
# Epoch 974, Minibatch 8/8, Test Error= 0.195266365765
# Epoch 975, Minibatch 8/8, Test Error= 0.197470413378
# Epoch 976, Minibatch 8/8, Test Error= 0.199003641122
# Epoch 977, Minibatch 8/8, Test Error= 0.195041746358
# Epoch 978, Minibatch 8/8, Test Error= 0.198131696101
# Epoch 979, Minibatch 8/8, Test Error= 0.195921136704
# Epoch 980, Minibatch 8/8, Test Error= 0.198176441024
# [array(0.9052924726883873), array(0.9640701908544133)]
# Testing Score= 0.934681331771
# Epoch 981, Minibatch 8/8, Test Error= 0.196813279625
# Epoch 982, Minibatch 8/8, Test Error= 0.196869865488
# Epoch 983, Minibatch 8/8, Test Error= 0.198868766097
# Epoch 984, Minibatch 8/8, Test Error= 0.19787682836
# Epoch 985, Minibatch 8/8, Test Error= 0.199236395079
# Epoch 986, Minibatch 8/8, Test Error= 0.196819765229
# Epoch 987, Minibatch 8/8, Test Error= 0.197062657271
# Epoch 988, Minibatch 8/8, Test Error= 0.199895139764
# Epoch 989, Minibatch 8/8, Test Error= 0.195393485648
# Epoch 990, Minibatch 8/8, Test Error= 0.198066603219
# [array(0.9065138093473777), array(0.962029042305508)]
# Testing Score= 0.934271425826
# Epoch 991, Minibatch 8/8, Test Error= 0.197044834663
# Epoch 992, Minibatch 8/8, Test Error= 0.197761359514
# Epoch 993, Minibatch 8/8, Test Error= 0.198099834777
# Epoch 994, Minibatch 8/8, Test Error= 0.196525952364
# Epoch 995, Minibatch 8/8, Test Error= 0.196193046735
# Epoch 996, Minibatch 8/8, Test Error= 0.199228349722
# Epoch 997, Minibatch 8/8, Test Error= 0.197467645923
# Epoch 998, Minibatch 8/8, Test Error= 0.197287203046
# Epoch 999, Minibatch 8/8, Test Error= 0.196794081962
# Epoch 1000, Minibatch 8/8, Test Error= 0.195434862611
# [array(0.9095118266988471), array(0.9598199946607167)]
# Testing Score= 0.93466591068
